# %% [markdown]
# ## Setup

# %%
# %matplotlib inline

# Path management
import os
from pathlib import Path

# Get main project directory 
main_dir = str(Path(os.path.abspath('')).parents[0])
os.chdir(main_dir)
print('main dir:',main_dir)
# Out:
# main dir: /Users/pablo/OneDrive/data-science/github/isuelogit

# %%
# Internal modules
from src import isuelogit as isl

# External modules
import sys
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# main dir: /Users/pablo/OneDrive/data-science/github/isuelogit

# %% [markdown]
# ## Read data from tntp repository

# %%
network_name = 'SiouxFalls'
# network_name = 'Eastern-Massachusetts'
# network_name =  'Berlin-Friedrichshain'
# network_name =  'Berlin-Mitte-Center'
# network_name =  'Barcelona'

links_df = isl.reader.read_tntp_linkdata(
    folderpath=os.getcwd() + "/input/public/networks/github/",
    subfoldername=network_name)

links_df['link_key'] = [(i, j, '0') for i, j in zip(links_df['init_node'], links_df['term_node'])]

# %% [markdown]
# ## Build network

# %%
network_generator = isl.factory.NetworkGenerator()

A = network_generator.generate_adjacency_matrix(links_keys=list(links_df['link_key'].values))

tntp_network = network_generator.build_network(A=A,network_name=network_name)
# Out:
# Creating SiouxFalls network
#
# Nodes: 24, Links: 76

# %% [markdown]
# ### Link performance functions

# %%
bpr_parameters_df = pd.DataFrame({'link_key': tntp_network.links_dict.keys(),
                                  'alpha': links_df.b,
                                  'beta': links_df.power,
                                  'tf': links_df.free_flow_time,
                                  'k': links_df.capacity
                                  })

tntp_network.set_bpr_functions(bprdata=bpr_parameters_df)

# %% [markdown]
# ### Exogenous link attributes

# %%
# Link features from TNTP repo

link_features_df = links_df[['link_key','length', 'speed', 'link_type', 'toll']]

# Generate synthetic link features
linkdata_generator = isl.factory.LinkDataGenerator()

synthetic_features_df = linkdata_generator.simulate_features(links=tntp_network.links,
                                                             features_Z= ['c', 'w', 's'],
                                                             option='continuous',
                                                             range=(0, 1))
n_sparse_features = 1 

sparse_features_df = linkdata_generator.simulate_features(
    links=tntp_network.links,
    features_Z= ['k' + str(i) for i in np.arange(0, n_sparse_features)],
    option='continuous',
    range=(-1, 1))

# Merge dataframes and load features data
link_features_df = link_features_df.merge(synthetic_features_df, left_on='link_key', right_on='link_key')
link_features_df = link_features_df.merge(sparse_features_df, left_on='link_key', right_on='link_key')
tntp_network.load_features_data(linkdata=link_features_df)

# %% [markdown]
# ### Utility function

# %%
utility_function = isl.estimation.UtilityFunction(features_Y=['tt'],
                                                  features_Z=['c', 's'],
                                                  true_values={'tt': -1, 'c': -6, 's': -3})

# Add parameters for sparse features
utility_function.add_sparse_features(Z=sparse_features_labels)

# %% [markdown]
# ### OD matrix

# %%
Q = isl.reader.read_tntp_od(folderpath=os.getcwd() + "/input/public/networks/github/",
                            subfoldername=network_name)

tntp_network.load_OD(Q= Q)
# Out:
# Reading Q from external file
# Matrix Q (24, 24) read in 0.0[s]
# 360600.0 trips were loaded among 528 o-d pairs

# %% [markdown]
# ## Paths

# %%
paths_generator = isl.factory.PathsGenerator()

paths_generator.load_k_shortest_paths(network=tntp_network, k=3)
# Out:
# Generating at most 3 paths per od
# 1584 paths were generated among 528 od pairs in 0.3 [s]
# 1584 paths were loaded in the network
# Updating incident matrices
# Matrix D (76, 1584) generated in 0.2[s].0%
# Matrix M (528, 1584) generated in 0.1[s]0%
# Matrix C (1584, 1584) generated in 0.0[s]

# %% [markdown]
# ### Equilibrator

# %%
equilibrator = isl.equilibrium.LUE_Equilibrator(network=tntp_network,
                                                utility_function=utility_function,
                                                uncongested_mode=False,
                                                max_iters=100,
                                                method='fw',
                                                iters_fw=100,
                                                search_fw='grid'
                                                # , path_size_correction = 20
                                                )

# %% [markdown]
# ### Synthetic traffic counts

# %%
counts, _ = linkdata_generator.simulate_counts(network=tntp_network,
                                               equilibrator=equilibrator,
                                               noise_params={'mu_x': 0, 'sd_x': 0},
                                               coverage=0.75
                                               )
tntp_network.load_traffic_counts(counts=counts)
# Out:
# Generating synthetic link counts via Frank-Wolfe
#
# SUE via fw (max iters: 100)
#
# Equilibrium gaps: ['9E-02', '3E-02', '2E-02', '1E-02', '9E-03', '7E-03', '5E-03', '4E-03', '3E-03', '1E-03', '2E-03', '1E-03', '1E-03', '1E-03', '4E-04', '3E-04', '3E-04', '3E-04', '2E-04', '2E-04', '2E-04', '1E-04', '4E-04', '3E-04', '2E-04', '1E-04', '2E-04', '6E-05']
# Initial Fisk Objective: -29,736,731.74
# Final Fisk Objective: -7,017,057.27
# Improvement Fisk Objective: 76.40%
# Final gap: 6E-05. Acc. bound: 1E-04. Time: 6.0 [s]
# Ratio of counts versus capacity: 109.3%
# Proportion of links over capacity: 56.6%
# Normalized RMSE: 0.0

# %% [markdown]
# ## Descriptive statistics

# %%
estimation_reporter = isl.writer.Reporter(foldername=network_name, seed = 2022)

# %% [markdown]
# ### Network topology

# %%
isl.descriptive_statistics.summary_table_networks([tntp_network])
# Out:
#       network  nodes  links  ods  paths
# 0  SiouxFalls     24     76  528   1584

# %% [markdown]
# ### Links data

# %%
summary_table_links_df = tntp_network.Z_data
estimation_reporter.write_table(df = summary_table_links_df, filename = 'links_data.csv', float_format = '%.3f')
summary_table_links_df
# Out:
#     link_type  alpha  beta   tf             k  length  speed  toll         c  \
# 0           1   0.15   4.0  6.0  25900.200640       6      0     0  0.048919
# 1           1   0.15   4.0  4.0  23403.473190       4      0     0  0.579357
# 2           1   0.15   4.0  6.0  25900.200640       6      0     0  0.863327
# 3           1   0.15   4.0  5.0   4958.180928       5      0     0  0.525146
# 4           1   0.15   4.0  4.0  23403.473190       4      0     0  0.662579
# ..        ...    ...   ...  ...           ...     ...    ...   ...       ...
# 71          1   0.15   4.0  4.0   5000.000000       4      0     0  0.029144
# 72          1   0.15   4.0  2.0   5078.508436       2      0     0  0.319147
# 73          1   0.15   4.0  4.0   5091.256152       4      0     0  0.554519
# 74          1   0.15   4.0  3.0   4885.357564       3      0     0  0.228984
# 75          1   0.15   4.0  2.0   5078.508436       2      0     0  0.523431
#
#            w         s        k0
# 0   0.309368  0.887144  0.935343
# 1   0.044589  0.283698 -0.940793
# 2   0.226561  0.305630  0.684137
# 3   0.553694  0.860258 -0.904635
# 4   0.619260  0.569881  0.439188
# ..       ...       ...       ...
# 71  0.457135  0.024753  0.058286
# 72  0.191700  0.199294  0.425143
# 73  0.145203  0.877723 -0.891202
# 74  0.677361  0.754692 -0.401849
# 75  0.449028  0.539440  0.353074
#
# [76 rows x 12 columns]

# %%
summary_table_links_df.describe()
# Out:
#        link_type  alpha  beta         tf             k     length  speed  \
# count       76.0  76.00  76.0  76.000000     76.000000  76.000000   76.0
# mean         1.0   0.15   4.0   4.131579  10247.206327   4.131579    0.0
# std          0.0   0.00   0.0   1.730835   7358.655049   1.730835    0.0
# min          1.0   0.15   4.0   2.000000   4823.950831   2.000000    0.0
# 25%          1.0   0.15   4.0   3.000000   4958.180928   3.000000    0.0
# 50%          1.0   0.15   4.0   4.000000   5109.391136   4.000000    0.0
# 75%          1.0   0.15   4.0   5.000000  14564.753150   5.000000    0.0
# max          1.0   0.15   4.0  10.000000  25900.200640  10.000000    0.0
#
#        toll          c          w          s         k0
# count  76.0  76.000000  76.000000  76.000000  76.000000
# mean    0.0   0.444113   0.478612   0.474832  -0.137287
# std     0.0   0.275610   0.276890   0.287555   0.568298
# min     0.0   0.020140   0.044589   0.002245  -0.957111
# 25%     0.0   0.185119   0.233300   0.216327  -0.648400
# 50%     0.0   0.511742   0.453082   0.430277  -0.200361
# 75%     0.0   0.664429   0.675679   0.757559   0.304350
# max     0.0   0.956890   0.982804   0.987683   0.935343

# %% [markdown]
# ## Bilevel optimization

# %%
outer_optimizer_norefined = isl.estimation.OuterOptimizer(
    method='ngd',
    iters=1,  # 10
    eta=1e-1,
    # path_size_correction = 1
)

learner_norefined = isl.estimation.Learner(
    equilibrator=equilibrator,
    outer_optimizer=outer_optimizer_norefined,
    utility_function=utility_function,
    network=tntp_network,
    name='norefined'
)

outer_optimizer_refined = isl.estimation.OuterOptimizer(
    # method='gauss-newton',
    method='lm',
    # method='ngd',
    # eta=1e-2,
    iters=10,
    # path_size_correction = 1
)

learner_refined = isl.estimation.Learner(
    network=tntp_network,
    equilibrator=equilibrator,
    outer_optimizer=outer_optimizer_refined,
    utility_function=utility_function,
    name='refined'
)

# %% [markdown]
# ### Benchmark predictions

# %% [markdown]
# ##### Naive prediction using mean counts

# %%
mean_counts_prediction_loss, mean_count_benchmark_model, \
    = isl.estimation.mean_count_prediction(x_bar=np.array(list(counts.values()))[:, np.newaxis])

print('\nObjective function under mean count prediction: ' + '{:,}'.format(round(mean_counts_prediction_loss, 1)))

# %% [markdown]
# #### Naive prediction where travelers make equilikely choices

# %%
equilikely_prediction_loss, x_eq_equilikely \
    = isl.estimation.loss_counts_uncongested_network(
    network = tntp_network,
    equilibrator=equilibrator,
    counts=tntp_network.counts_vector,
    utility_function=utility_function)

print('Objective function under equilikely route choices: ' + '{:,}'.format(round(equilikely_prediction_loss, 1)))

# %% [markdown]
# ### Estimation

# %% [markdown]
# #### No refined stage

# %%
learning_results_norefined, inference_results_norefined, best_iter_norefined = \
    learner_norefined.statistical_inference(h0=0, bilevel_iters=10, alpha=0.05, iteration_report = True)

theta_norefined = learning_results_norefined[best_iter_norefined]['theta']
# Out:
# Bilevel optimization for SiouxFalls network
#
# Iteration : 1/10
#
# Initial theta: {'tt': '0.0E+00', 'c': '0.0E+00', 's': '0.0E+00', 'k0': '0.0E+00'}
#
# SUE via fw (max iters: 100)
#
# Equilibrium gaps: ['0E+00']
# Initial Fisk Objective: -2,099,207.0
# Final Fisk Objective: -2,099,207.0
# Improvement Fisk Objective: 0.00%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 0.4 [s]
# Initial objective: 2,061,126,961
# Initial RMSE: 6013.3
# Initial Normalized RMSE: 0.543
#
# Iteration : 2/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-1.0E-01', 'c': '-8.5E-05', 's': '-1.9E-04', 'k0': '-6.7E-06'}
# Current ratio theta: 1182.386
# time: 0.2[s]
#
# SUE via fw (max iters: 100)
#
# Equilibrium gaps: ['3E-02', '1E-02', '4E-03', '3E-03', '4E-04', '2E-04', '1E-04', '0E+00']
# Initial Fisk Objective: -3,254,333.16
# Final Fisk Objective: -2,424,203.8
# Improvement Fisk Objective: 25.51%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 2.4 [s]
#
# Time current iteration: 2.6 [s]
# Current objective_value: 122,180,058
# Current objective improvement: 94.07%
# Current RMSE: 1464.1
# Current Normalized RMSE: 0.132
# Marginal objective improvement: 94.07%
# Marginal objective improvement value: 1,938,946,902.9
#
#
# Iteration : 3/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-2.0E-01', 'c': '-9.9E-03', 's': '-9.0E-03', 'k0': '8.8E-03'}
# Current ratio theta: 19.987
# time: 0.2[s]
#
# SUE via fw (max iters: 100)
#
# Equilibrium gaps: ['7E-02', '2E-02', '8E-03', '4E-03', '3E-03', '1E-03', '1E-03', '3E-04', '8E-05']
# Initial Fisk Objective: -3,938,021.45
# Final Fisk Objective: -2,582,652.97
# Improvement Fisk Objective: 34.42%
# Final gap: 8E-05. Acc. bound: 1E-04. Time: 2.6 [s]
#
# Time current iteration: 2.8 [s]
# Current objective_value: 65,897,305
# Current objective improvement: 96.80%
# Current RMSE: 1075.2
# Current Normalized RMSE: 0.097
# Marginal objective improvement: 46.07%
# Marginal objective improvement value: 56,282,752.6
#
#
# Iteration : 4/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-2.9E-01', 'c': '-2.8E-02', 's': '-2.1E-02', 'k0': '3.0E-02'}
# Current ratio theta: 10.6603
# time: 0.2[s]
#
# SUE via fw (max iters: 100)
#
# Equilibrium gaps: ['1E-01', '3E-02', '1E-02', '8E-03', '5E-03', '3E-03', '2E-03', '1E-03', '1E-03', '4E-04', '1E-04', '1E-05']
# Initial Fisk Objective: -4,788,464.33
# Final Fisk Objective: -2,719,815.69
# Improvement Fisk Objective: 43.20%
# Final gap: 1E-05. Acc. bound: 1E-04. Time: 5.9 [s]
#
# Time current iteration: 6.1 [s]
# Current objective_value: 39,987,549
# Current objective improvement: 98.06%
# Current RMSE: 837.6
# Current Normalized RMSE: 0.076
# Marginal objective improvement: 39.32%
# Marginal objective improvement value: 25,909,756.3
#
#
# Iteration : 5/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-3.8E-01', 'c': '-6.7E-02', 's': '-3.7E-02', 'k0': '6.3E-02'}
# Current ratio theta: 5.6611
# time: 0.2[s]
#
# SUE via fw (max iters: 100)
#
# Equilibrium gaps: ['1E-01', '3E-02', '2E-02', '1E-02', '7E-03', '4E-03', '3E-03', '2E-03', '2E-03', '8E-04', '4E-04', '1E-04', '9E-05']
# Initial Fisk Objective: -5,754,566.15
# Final Fisk Objective: -2,846,142.97
# Improvement Fisk Objective: 50.54%
# Final gap: 9E-05. Acc. bound: 1E-04. Time: 3.5 [s]
#
# Time current iteration: 3.7 [s]
# Current objective_value: 30,133,712
# Current objective improvement: 98.54%
# Current RMSE: 727.1
# Current Normalized RMSE: 0.066
# Marginal objective improvement: 24.64%
# Marginal objective improvement value: 9,853,837.2
#
#
# Iteration : 6/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-4.7E-01', 'c': '-9.7E-02', 's': '-7.3E-02', 'k0': '8.0E-02'}
# Current ratio theta: 4.8036
# time: 0.2[s]
#
# SUE via fw (max iters: 100)
#
# Equilibrium gaps: ['1E-01', '3E-02', '2E-02', '1E-02', '8E-03', '5E-03', '4E-03', '2E-03', '3E-03', '1E-03', '2E-03', '2E-04', '3E-05']
# Initial Fisk Objective: -6,954,853.29
# Final Fisk Objective: -2,974,040.23
# Improvement Fisk Objective: 57.24%
# Final gap: 3E-05. Acc. bound: 1E-04. Time: 3.4 [s]
#
# Time current iteration: 3.6 [s]
# Current objective_value: 25,582,807
# Current objective improvement: 98.76%
# Current RMSE: 669.9
# Current Normalized RMSE: 0.061
# Marginal objective improvement: 15.10%
# Marginal objective improvement value: 4,550,904.4
#
#
# Iteration : 7/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-5.3E-01', 'c': '-1.4E-01', 's': '-1.3E-01', 'k0': '1.2E-01'}
# Current ratio theta: 3.7993
# time: 0.2[s]
#
# SUE via fw (max iters: 100)
#
# Equilibrium gaps: ['1E-01', '3E-02', '2E-02', '1E-02', '9E-03', '6E-03', '5E-03', '2E-03', '4E-03', '2E-03', '5E-04', '5E-04', '2E-04', '4E-04', '2E-04', '3E-04', '6E-05']
# Initial Fisk Objective: -7,857,777.81
# Final Fisk Objective: -3,084,861.01
# Improvement Fisk Objective: 60.74%
# Final gap: 6E-05. Acc. bound: 1E-04. Time: 4.5 [s]
#
# Time current iteration: 4.7 [s]
# Current objective_value: 21,745,328
# Current objective improvement: 98.94%
# Current RMSE: 617.7
# Current Normalized RMSE: 0.056
# Marginal objective improvement: 15.00%
# Marginal objective improvement value: 3,837,478.9
#
#
# Iteration : 8/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-6.1E-01', 'c': '-1.3E-01', 's': '-1.8E-01', 'k0': '1.1E-01'}
# Current ratio theta: 4.6398
# time: 0.2[s]
#
# SUE via fw (max iters: 100)
#
# Equilibrium gaps: ['2E-01', '4E-02', '2E-02', '1E-02', '1E-02', '7E-03', '6E-03', '3E-03', '4E-03', '2E-03', '3E-03', '1E-03', '6E-05']
# Initial Fisk Objective: -9,293,090.95
# Final Fisk Objective: -3,198,746.17
# Improvement Fisk Objective: 65.58%
# Final gap: 6E-05. Acc. bound: 1E-04. Time: 3.6 [s]
#
# Time current iteration: 3.8 [s]
# Current objective_value: 24,178,276
# Current objective improvement: 98.94%
# Current RMSE: 651.3
# Current Normalized RMSE: 0.059
# Marginal objective improvement: -11.19%
# Marginal objective improvement value: -2,432,947.3
#
#
# Iteration : 9/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-6.6E-01', 'c': '-1.8E-01', 's': '-1.5E-01', 'k0': '1.7E-01'}
# Current ratio theta: 3.6508
# time: 0.2[s]
#
# SUE via fw (max iters: 100)
#
# Equilibrium gaps: ['2E-01', '4E-02', '3E-02', '2E-02', '1E-02', '7E-03', '6E-03', '3E-03', '4E-03', '2E-03', '5E-04', '9E-04', '3E-04', '6E-04', '7E-04', '6E-05']
# Initial Fisk Objective: -10,006,277.81
# Final Fisk Objective: -3,268,170.96
# Improvement Fisk Objective: 67.34%
# Final gap: 6E-05. Acc. bound: 1E-04. Time: 7.8 [s]
#
# Time current iteration: 8.0 [s]
# Current objective_value: 22,618,705
# Current objective improvement: 98.94%
# Current RMSE: 629.9
# Current Normalized RMSE: 0.057
# Marginal objective improvement: 6.45%
# Marginal objective improvement value: 1,559,570.2
#
#
# Iteration : 10/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-6.8E-01', 'c': '-2.4E-01', 's': '-1.1E-01', 'k0': '2.4E-01'}
# Current ratio theta: 2.881
# time: 0.3[s]
#
# SUE via fw (max iters: 100)
#
# Equilibrium gaps: ['1E-01', '4E-02', '2E-02', '2E-02', '1E-02', '7E-03', '6E-03', '4E-03', '6E-03', '3E-03', '4E-04', '1E-03', '6E-04', '5E-04', '7E-04', '1E-04', '4E-05']
# Initial Fisk Objective: -10,186,612.68
# Final Fisk Objective: -3,297,870.45
# Improvement Fisk Objective: 67.63%
# Final gap: 4E-05. Acc. bound: 1E-04. Time: 6.1 [s]
#
# Time current iteration: 6.4 [s]
# Current objective_value: 20,611,332
# Current objective improvement: 99.00%
# Current RMSE: 601.3
# Current Normalized RMSE: 0.054
# Marginal objective improvement: 8.87%
# Marginal objective improvement value: 2,007,373.4
#
# Summary results of bilevel optimization
# best iter: 10
# best theta: {'tt': '-6.8E-01', 'c': '-2.4E-01', 's': '-1.1E-01', 'k0': '2.4E-01'}
# best ratio theta: 2.881
# best objective_value: 20,611,332
# Final best objective improvement: 99.00%
# Final best objective improvement value: 2,040,515,628.6
# Best RMSE: 601.3
# Best Normalized RMSE: 0.054
# Total time: 41.6 [s]
#
# Performing hypothesis testing (H0: theta = 0, alpha = 0.05)
# Hessian approximated as J^T J
#
# Summary of parameters:
#  parameter    est               CI  width_CI  t-test  p-value
#        tt -0.679 [-0.797, -0.562]     0.117 -11.610    0.000
#         c -0.236  [-0.432, -0.04]     0.196  -2.415    0.019
#         s -0.109  [-0.352, 0.134]     0.243  -0.900    0.372
#        k0  0.243   [0.093, 0.393]     0.150   3.239    0.002
#
# Computing F-test
#
# Summary of model:
#         F  critical-F     p  n  dof_m1  dof_m2         sse_m1       sse_m2
# 1363.521       2.546 0.000 57       0       4 2061126960.639 19836220.634
# Time: 0.3[s]

# %% [markdown]
# #### Refined stage

# %%
learner_refined.utility_function.initial_values = theta_norefined

learning_results_refined, inference_results_refined, best_iter_refined = \
    learner_refined.statistical_inference(h0=0, bilevel_iters=10, alpha=0.05, iteration_report = True)
# Out:
# Bilevel optimization for SiouxFalls network
#
# Iteration : 1/10
#
# Initial theta: {'tt': '-6.8E-01', 'c': '-2.4E-01', 's': '-1.1E-01', 'k0': '2.4E-01'}
# Initial ratio theta: 2.881
#
# SUE via fw (max iters: 100)
#
# Equilibrium gaps: ['1E-01', '4E-02', '2E-02', '2E-02', '1E-02', '7E-03', '6E-03', '4E-03', '6E-03', '3E-03', '4E-04', '1E-03', '6E-04', '5E-04', '7E-04', '1E-04', '4E-05']
# Initial Fisk Objective: -10,186,612.68
# Final Fisk Objective: -3,297,870.45
# Improvement Fisk Objective: 67.63%
# Final gap: 4E-05. Acc. bound: 1E-04. Time: 6.1 [s]
# Initial objective: 20,611,332
# Initial RMSE: 601.3
# Initial Normalized RMSE: 0.054
#
# Iteration : 2/10
#
# Learning  params via lm (10 iters )
#
# Damping factors: ['1.0E-02', '5.0E-03', '2.5E-03']
# theta: {'tt': '-6.4E-01', 'c': '-3.7E-01', 's': '-7.2E-01', 'k0': '4.3E-01'}
# Current ratio theta: 1.76
# time: 0.9[s]
#
# SUE via fw (max iters: 100)
#
# Equilibrium gaps: ['1E-01', '3E-02', '2E-02', '1E-02', '1E-02', '7E-03', '7E-03', '3E-03', '4E-03', '2E-03', '7E-04', '4E-04', '3E-04', '3E-04', '2E-04', '2E-04', '2E-04', '2E-04', '1E-04', '5E-04', '0E+00']
# Initial Fisk Objective: -9,762,952.66
# Final Fisk Objective: -3,584,815.75
# Improvement Fisk Objective: 63.28%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 7.6 [s]
#
# Time current iteration: 8.4 [s]
# Current objective_value: 14,465,477
# Current objective improvement: 29.82%
# Current RMSE: 503.8
# Current Normalized RMSE: 0.045
# Marginal objective improvement: 29.82%
# Marginal objective improvement value: 6,145,855.4
#
#
# Iteration : 3/10
#
# Learning  params via lm (10 iters )
#
# Damping factors: ['1.0E-02', '5.0E-03']
# theta: {'tt': '-7.2E-01', 'c': '-5.5E-01', 's': '-8.4E-01', 'k0': '6.9E-01'}
# Current ratio theta: 1.3151
# time: 0.6[s]
#
# SUE via fw (max iters: 100)
#
# Equilibrium gaps: ['1E-01', '3E-02', '2E-02', '1E-02', '2E-02', '9E-03', '6E-03', '2E-03', '8E-04', '2E-03', '1E-03', '1E-03', '1E-03', '2E-04', '3E-04', '2E-04', '6E-04', '3E-04', '1E-04', '1E-04', '1E-04', '5E-05']
# Initial Fisk Objective: -10,854,267.99
# Final Fisk Objective: -3,814,103.15
# Improvement Fisk Objective: 64.86%
# Final gap: 5E-05. Acc. bound: 1E-04. Time: 7.9 [s]
#
# Time current iteration: 8.5 [s]
# Current objective_value: 12,845,762
# Current objective improvement: 37.68%
# Current RMSE: 474.7
# Current Normalized RMSE: 0.043
# Marginal objective improvement: 11.20%
# Marginal objective improvement value: 1,619,714.2
#
#
# Iteration : 4/10
#
# Learning  params via lm (10 iters )
#
# Damping factors: ['1.0E-02', '5.0E-03']
# theta: {'tt': '-8.6E-01', 'c': '-3.5E-01', 's': '-1.8E+00', 'k0': '6.9E-01'}
# Current ratio theta: 2.4776
# time: 0.6[s]
#
# SUE via fw (max iters: 100)
#
# Equilibrium gaps: ['1E-01', '4E-02', '2E-02', '1E-02', '1E-02', '8E-03', '7E-03', '4E-03', '4E-03', '2E-03', '3E-03', '1E-03', '1E-03', '7E-04', '1E-03', '4E-04', '7E-05']
# Initial Fisk Objective: -13,701,200.96
# Final Fisk Objective: -4,304,487.13
# Improvement Fisk Objective: 68.58%
# Final gap: 7E-05. Acc. bound: 1E-04. Time: 6.4 [s]
#
# Time current iteration: 7.0 [s]
# Current objective_value: 13,508,796
# Current objective improvement: 37.68%
# Current RMSE: 486.8
# Current Normalized RMSE: 0.044
# Marginal objective improvement: -5.16%
# Marginal objective improvement value: -663,034.0
#
#
# Iteration : 5/10
#
# Learning  params via lm (10 iters )
#
# Damping factors: ['1.0E-02', '5.0E-03', '2.5E-03']
# theta: {'tt': '-9.8E-01', 'c': '-5.0E-01', 's': '-2.5E+00', 'k0': '8.7E-01'}
# Current ratio theta: 1.9725
# time: 1.1[s]
#
# SUE via fw (max iters: 100)
#
# Equilibrium gaps: ['1E-01', '5E-02', '2E-02', '2E-02', '2E-02', '6E-03', '5E-03', '5E-03', '3E-03', '4E-03', '2E-03', '2E-03', '2E-03', '4E-04', '8E-04', '4E-04', '7E-04', '1E-03', '9E-05']
# Initial Fisk Objective: -16,355,344.92
# Final Fisk Objective: -4,790,464.32
# Improvement Fisk Objective: 70.71%
# Final gap: 9E-05. Acc. bound: 1E-04. Time: 10.0 [s]
#
# Time current iteration: 11.1 [s]
# Current objective_value: 11,439,416
# Current objective improvement: 44.50%
# Current RMSE: 448.0
# Current Normalized RMSE: 0.04
# Marginal objective improvement: 15.32%
# Marginal objective improvement value: 2,069,380.2
#
#
# Iteration : 6/10
#
# Learning  params via lm (10 iters )
#
# Damping factors: ['1.0E-02', '5.0E-03']
# theta: {'tt': '-1.7E+00', 'c': '-1.5E+00', 's': '-3.8E+00', 'k0': '1.4E+00'}
# Current ratio theta: 1.1467
# time: 1.9[s]
#
# SUE via fw (max iters: 100)
#
# Equilibrium gaps: ['2E-01', '7E-02', '3E-02', '2E-02', '2E-02', '1E-02', '8E-03', '8E-03', '4E-03', '5E-03', '3E-03', '1E-03', '2E-03', '1E-03', '2E-03', '2E-03', '4E-04', '2E-04', '5E-04', '3E-04', '1E-03', '4E-04', '1E-04', '2E-04', '8E-05']
# Initial Fisk Objective: -30,669,840.7
# Final Fisk Objective: -6,506,586.7
# Improvement Fisk Objective: 78.79%
# Final gap: 8E-05. Acc. bound: 1E-04. Time: 9.1 [s]
#
# Time current iteration: 11.1 [s]
# Current objective_value: 10,242,879
# Current objective improvement: 50.30%
# Current RMSE: 423.9
# Current Normalized RMSE: 0.038
# Marginal objective improvement: 10.46%
# Marginal objective improvement value: 1,196,536.7
#
#
# Iteration : 7/10
#
# Learning  params via lm (10 iters )
#
# Damping factors: ['1.0E-02', '5.0E-03']
# theta: {'tt': '-2.7E+00', 'c': '-3.6E+00', 's': '-4.6E+00', 'k0': '2.1E+00'}
# Current ratio theta: 0.7523
# time: 0.6[s]
#
# SUE via fw (max iters: 100)
#
# Equilibrium gaps: ['2E-01', '9E-02', '4E-02', '3E-02', '3E-02', '9E-03', '8E-03', '9E-03', '6E-03', '3E-03', '8E-03', '4E-03', '1E-03', '8E-04', '2E-03', '1E-03', '1E-03', '1E-03', '4E-04', '3E-04', '5E-04', '4E-04', '6E-04', '3E-04', '8E-04', '8E-04', '2E-05']
# Initial Fisk Objective: -51,004,235.75
# Final Fisk Objective: -8,806,076.77
# Improvement Fisk Objective: 82.73%
# Final gap: 2E-05. Acc. bound: 1E-04. Time: 9.8 [s]
#
# Time current iteration: 10.4 [s]
# Current objective_value: 8,904,220
# Current objective improvement: 56.80%
# Current RMSE: 395.2
# Current Normalized RMSE: 0.036
# Marginal objective improvement: 13.07%
# Marginal objective improvement value: 1,338,659.5
#
#
# Iteration : 8/10
#
# Learning  params via lm (10 iters )
#
# Damping factors: ['1.0E-02', '5.0E-03']
# theta: {'tt': '-4.8E+00', 'c': '-6.1E+00', 's': '-8.0E+00', 'k0': '2.8E+00'}
# Current ratio theta: 0.7779
# time: 1.6[s]
#
# SUE via fw (max iters: 100)
#
# Equilibrium gaps: ['3E-01', '7E-02', '4E-02', '3E-02', '3E-02', '2E-02', '2E-02', '1E-02', '1E-02', '7E-03', '6E-03', '5E-03', '2E-03', '1E-03', '2E-03', '1E-03', '8E-04', '2E-03', '5E-04', '2E-04', '2E-03', '1E-03', '4E-05']
# Initial Fisk Objective: -89,766,419.55
# Final Fisk Objective: -13,516,318.09
# Improvement Fisk Objective: 84.94%
# Final gap: 4E-05. Acc. bound: 1E-04. Time: 8.1 [s]
#
# Time current iteration: 9.7 [s]
# Current objective_value: 9,902,137
# Current objective improvement: 56.80%
# Current RMSE: 416.8
# Current Normalized RMSE: 0.038
# Marginal objective improvement: -11.21%
# Marginal objective improvement value: -997,917.1
#
#
# Iteration : 9/10
#
# Learning  params via lm (10 iters )
#
# Damping factors: ['1.0E-02', '5.0E-03']
# theta: {'tt': '-1.1E+01', 'c': '-1.5E+01', 's': '-1.7E+01', 'k0': '6.3E+00'}
# Current ratio theta: 0.7276
# time: 0.5[s]
#
# SUE via fw (max iters: 100)
#
# Equilibrium gaps: ['3E-01', '8E-02', '4E-02', '4E-02', '3E-02', '2E-02', '2E-02', '2E-02', '7E-03', '2E-02', '7E-03', '3E-03', '3E-03', '3E-03', '5E-04', '2E-03', '9E-04', '1E-03', '1E-03', '1E-03', '9E-04', '7E-04', '4E-04', '2E-03', '2E-03', '5E-05']
# Initial Fisk Objective: -213,762,837.3
# Final Fisk Objective: -27,642,694.52
# Improvement Fisk Objective: 87.07%
# Final gap: 5E-05. Acc. bound: 1E-04. Time: 12.1 [s]
#
# Time current iteration: 12.7 [s]
# Current objective_value: 10,430,099
# Current objective improvement: 56.80%
# Current RMSE: 427.8
# Current Normalized RMSE: 0.039
# Marginal objective improvement: -5.33%
# Marginal objective improvement value: -527,962.2
#
#
# Iteration : 10/10
#
# Learning  params via lm (10 iters )
#
# Damping factors: ['1.0E-02', '5.0E-03']
# theta: {'tt': '-1.7E+01', 'c': '-2.2E+01', 's': '-2.9E+01', 'k0': '1.0E+01'}
# Current ratio theta: 0.785
# time: 0.6[s]
#
# SUE via fw (max iters: 100)
#
# Equilibrium gaps: ['3E-01', '1E-01', '6E-02', '5E-02', '3E-02', '1E-02', '1E-02', '1E-02', '1E-02', '8E-03', '4E-03', '2E-03', '7E-03', '3E-03', '2E-03', '2E-03', '3E-03', '8E-04', '8E-04', '1E-03', '2E-03', '2E-04', '1E-04', '3E-04', '0E+00']
# Initial Fisk Objective: -322,171,344.87
# Final Fisk Objective: -42,702,397.35
# Improvement Fisk Objective: 86.75%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 10.2 [s]
#
# Time current iteration: 10.8 [s]
# Current objective_value: 10,659,637
# Current objective improvement: 56.80%
# Current RMSE: 432.4
# Current Normalized RMSE: 0.039
# Marginal objective improvement: -2.20%
# Marginal objective improvement value: -229,537.6
#
# Summary results of bilevel optimization
# best iter: 7
# best theta: {'tt': '-2.7E+00', 'c': '-3.6E+00', 's': '-4.6E+00', 'k0': '2.1E+00'}
# best ratio theta: 0.7523
# best objective_value: 8,904,220
# Final best objective improvement: 56.80%
# Final best objective improvement value: 11,707,112.1
# Best RMSE: 395.2
# Best Normalized RMSE: 0.036
# Total time: 89.7 [s]
#
# Performing hypothesis testing (H0: theta = 0, alpha = 0.05)
# Hessian approximated as J^T J
#
# Summary of parameters:
#  parameter    est               CI  width_CI  t-test  p-value
#        tt -2.699 [-3.169, -2.229]     0.470 -11.518    0.000
#         c -3.588 [-4.267, -2.908]     0.679 -10.591    0.000
#         s -4.557 [-5.298, -3.816]     0.741 -12.340    0.000
#        k0  2.051   [1.695, 2.406]     0.355  11.580    0.000
#
# Computing F-test
#
# Summary of model:
#        F  critical-F     p  n  dof_m1  dof_m2         sse_m1       sse_m2
# 749.123       2.546 0.000 57       0       4 2061126960.639 35822275.505
# Time: 0.3[s]

# %% [markdown]
# #### Reports

# %%
estimation_reporter.add_items_report(
    theta_norefined=theta_norefined,
    theta_refined=learning_results_refined[best_iter_refined]['theta'],
    best_objective_norefined = learning_results_norefined[best_iter_norefined]['objective'],
    best_objective_refined = learning_results_refined[best_iter_refined]['objective'],
    mean_count=mean_count_benchmark_model,
    mean_counts_prediction_loss = mean_counts_prediction_loss,
    equilikely_prediction_loss = equilikely_prediction_loss
)

# Summary with most relevant options, prediction error, initial parameters, etc
estimation_reporter.write_estimation_report(
    network=tntp_network,
    learners=[learner_norefined, learner_refined],
    linkdata_generator=linkdata_generator,
    utility_function=utility_function)

# Write tables with results on learning and inference
estimation_reporter.write_learning_tables(
    results_norefined=learning_results_norefined,
    results_refined=learning_results_refined,
    network = tntp_network,
    utility_function = utility_function,
    simulated_data = True)

estimation_reporter.write_inference_tables(
    results_norefined=inference_results_norefined,
    results_refined=inference_results_refined,
    float_format = '%.3f')

# %% [markdown]
# ### Visualizations

# %% [markdown]
# #### Convergence

# %%
results_df = isl.descriptive_statistics \
    .get_loss_and_estimates_over_iterations(results_norefined=learning_results_norefined
                                            , results_refined=learning_results_refined)

fig = isl.visualization.Artist().convergence(
    results_norefined_df=results_df[results_df['stage'] == 'norefined'],
    results_refined_df=results_df[results_df['stage'] == 'refined'],
    simulated_data= True,
    filename='convergence_' + tntp_network.key,
    methods=[outer_optimizer_norefined.options['method'], outer_optimizer_refined.options['method']],
    theta_true = utility_function.true_values,
    folder = estimation_reporter.dirs['estimation_folder']
)

fig.savefig(estimation_reporter.dirs['estimation_folder'] + '/' + 'bilevel_optimization_convergence.pdf',
            pad_inches=0.1, bbox_inches="tight")

plt.show()

plt.close(fig)

# %% [markdown]
# #### Distribution of errors across link counts

# %%
best_x_norefined = np.array(list(learning_results_norefined[best_iter_refined]['x'].values()))[:, np.newaxis]
best_x_refined = np.array(list(learning_results_refined[best_iter_refined]['x'].values()))[:, np.newaxis]

fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True, figsize=(8, 4))

# We can set the number of bins with the `bins` kwarg
axs[0].hist(isl.estimation.error_by_link(observed_counts=tntp_network.counts_vector, predicted_counts=best_x_norefined))
axs[1].hist(isl.estimation.error_by_link(observed_counts=tntp_network.counts_vector, predicted_counts=best_x_refined))

for axi in [axs[0], axs[1]]:
    axi.tick_params(axis='x', labelsize=16)
    axi.tick_params(axis='y', labelsize=16)

fig.savefig(estimation_reporter.dirs['estimation_folder'] + '/' + 'distribution_predicted_count_error.pdf',
            pad_inches=0.1, bbox_inches="tight")

plt.show()

plt.close(fig)

# %% [markdown]
# #### Heatmap O-D matrix

# %%
rows, cols = tntp_network.Q.shape

od_df = pd.DataFrame({'origin': pd.Series([], dtype=int)
                         , 'destination': pd.Series([], dtype=int)
                         , 'trips': pd.Series([], dtype=int)})

counter = 0
for origin in range(0, rows):
    for destination in range(0, cols):
        # od_df.loc[counter] = [(origin+1,destination+1), N['train'][current_network].Q[(origin,destination)]]
        od_df.loc[counter] = [int(origin + 1), int(destination + 1), tntp_network.Q[(origin, destination)]]
        counter += 1

od_df.origin = od_df.origin.astype(int)
od_df.destination = od_df.destination.astype(int)

od_pivot_df = od_df.pivot_table(index='origin', columns='destination', values='trips')

fig, ax = plt.subplots(figsize=(8, 6))
ax = sns.heatmap(od_pivot_df, linewidth=0.5, cmap="Blues")

plt.show()

fig.savefig(estimation_reporter.dirs['estimation_folder'] + '/' + 'heatmap_OD_matrix.pdf',
            pad_inches=0.1, bbox_inches="tight")
plt.close(fig)
