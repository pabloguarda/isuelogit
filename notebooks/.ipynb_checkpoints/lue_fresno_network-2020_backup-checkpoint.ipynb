# %% [markdown]
# ## Setup

# %%
# %matplotlib inline

# External modules
import ast
import numpy as np
import pandas as pd
from sklearn import preprocessing
import matplotlib.pyplot as plt
import os
from pathlib import Path

import warnings
warnings.simplefilter(action = "ignore", category = RuntimeWarning)

# %%
# Path management
main_dir = str(Path(os.path.abspath('')).parents[0])
os.chdir(main_dir)
print('main dir:',main_dir)
# Out:
# main dir: /Users/pablo/OneDrive/data-science/github/isuelogit

# %%
# Internal modules
from src import isuelogit as isl

# %%
# Seed
_SEED = 2022

# %% [markdown]
# ## Read network data from Fresno

# %%
network_name = 'Fresno'

# To write estimation report and set seed for all algorithms involving some randomness  
estimation_reporter = isl.writer.Reporter(
    folderpath = isl.config.dirs['output_folder'] + 'estimations/' + network_name, seed = _SEED)

# Reader of geospatial and spatio-temporal data
data_reader = isl.etl.DataReader(network_key=network_name)

# First Tuesday of October, 2019
data_reader.select_period(date='2019-10-01', hour=16)

# Read nodes data
nodes_df = pd.read_csv(isl.dirs['input_folder'] + '/network-data/nodes/'  + 'fresno-nodes-data.csv')

# Read spatiotemporal link data
links_df = pd.read_csv(
    isl.dirs['input_folder'] + 'network-data/links/' + str(data_reader.options['selected_date'])+ '-fresno-link-data.csv',
    converters={"link_key": ast.literal_eval,"pems_id": ast.literal_eval})
# Out:
# Selected date is 2019-10-01, Tuesday at 16:00

# %% [markdown]
# ## Build network

# %%
network_generator = isl.factory.NetworkGenerator()

A = network_generator.generate_adjacency_matrix(links_keys=list(links_df['link_key'].values))

fresno_network = \
    network_generator.build_fresno_network(A=A, links_df=links_df, nodes_df=nodes_df, network_name= network_name)
# Out:
# Creating Fresno network
#
# Nodes: 1789, Links: 2413

# %% [markdown]
# ### OD matrix

# %%
network_generator.read_OD(network=fresno_network, sparse=True)
# Out:
# Matrix Q (1789, 1789) read in 0.0[s] with sparse format
# 66266.34839999994 trips were loaded among 6970 o-d pairs

# %% [markdown]
# ### Paths

# %%
paths_generator = isl.factory.PathsGenerator()

# # Generate and Load paths in network
# paths_generator.load_k_shortest_paths(network = fresno_network, k=3)

paths_generator.read_paths(network=fresno_network, update_incidence_matrices=True)
# Out:
# 26380 paths were read in 5.8[s]| 100.0%
# 26380 paths were loaded in the network
# Updating incidence matrices
# Matrix D (2413, 26380) generated in 22.2[s]
# Matrix M (6970, 26380) generated in 1.1[s]
# Matrix C (26380, 26380) generated in 6.4[s]

# %% [markdown]
# ### Link performance functions

# %%
bpr_parameters_df = pd.DataFrame({'link_key': links_df['link_key'],
                                  'alpha': links_df['alpha'],
                                  'beta': links_df['beta'],
                                  'tf': links_df['tf'],
                                  'k': pd.to_numeric(links_df['k'], errors='coerce', downcast='float')
                                  })

# Normalize free flow travel time between 0 and 1
bpr_parameters_df['tf'] = pd.DataFrame(preprocessing.MinMaxScaler().fit_transform(np.array(bpr_parameters_df['tf']).reshape(-1, 1)))

fresno_network.set_bpr_functions(bprdata=bpr_parameters_df)

# %% [markdown]
# ### Feature Engineering

# %%
fresno_network.load_features_data(links_df, link_key = 'link_key')

isl.etl.feature_engineering_fresno(links=fresno_network.links, network=fresno_network)
# Out:
# Features values of links with a type different than LWRLK were set to 0
# New features: ['low_inc', 'high_inc', 'no_incidents', 'no_bus_stops', 'no_intersections', 'tt_sd_adj', 'tt_reliability']

# %%
features_list = ['median_inc', 'intersections', 'incidents', 'bus_stops', 'median_age',
                 'tt_avg', 'tt_sd','tt_var', 'tt_cv', 'tt_sd_adj','tt_reliability',
                 'speed_ref_avg', 'speed_avg', 'speed_hist_avg','speed_sd','speed_hist_sd','speed_cv']


# Normalization of features to range [0,1]
linkdata = pd.DataFrame(preprocessing.MinMaxScaler().fit_transform(fresno_network.Z_data[features_list].values))
linkdata.columns = features_list
linkdata.insert(0, 'link_key', fresno_network.links_keys)

fresno_network.load_features_data(linkdata)

# %% [markdown]
# ### Traffic counts

# %%
counts_df = pd.read_csv(isl.dirs['input_folder'] + '/network-data/links/' \
                            + str(data_reader.options['selected_date']) + '-fresno-link-counts' + '.csv',
                        converters={'link_key': ast.literal_eval})

counts = dict(zip(counts_df['link_key'].values, counts_df['counts'].values))

fresno_network.load_traffic_counts(counts=counts)

# %% [markdown]
# ## Descriptive statistics

# %% [markdown]
# ### Link coverage

# %%
total_counts_observations = np.count_nonzero(~np.isnan(np.array(list(counts.values()))))

total_links = np.array(list(counts.values())).shape[0]

print('\nTotal link counts observations: ' + str(total_counts_observations))
print('Link coverage: ' + "{:.1%}".format(round(total_counts_observations / total_links, 4)))
# Out:
# Total link counts observations: 141
# Link coverage: 5.8%

# %% [markdown]
# ### Networks topology

# %%
isl.descriptive_statistics.summary_table_networks([fresno_network])
# Out:
#   network  nodes  links   ods  paths
# 0  Fresno   1789   2413  6970  26380

# %% [markdown]
# ### Links data

# %%
summary_table_links_df = fresno_network.Z_data
estimation_reporter.write_table(df = summary_table_links_df, filename = 'links_data.csv', float_format = '%.3f')
summary_table_links_df
# Out:
#      link_type  alpha  beta     tf             k  observed  counts  \
# 0        LWRLK   0.15   4.0  0.098  1.800000e+03         0     NaN
# 1        LWRLK   0.15   4.0  0.169  1.800000e+03         0     NaN
# 2        LWRLK   0.15   4.0  0.396  2.400000e+03         0     NaN
# 3        LWRLK   0.15   4.0  0.192  2.000000e+03         0     NaN
# 4        LWRLK   0.15   4.0  0.105  1.800000e+03         0     NaN
# ...        ...    ...   ...    ...           ...       ...     ...
# 2408     PQULK   0.15   4.0  0.000  4.990000e+09         0     NaN
# 2409     PQULK   0.15   4.0  0.000  4.990000e+09         0     NaN
# 2410     LWRLK   0.15   4.0  0.045  1.800000e+03         0     NaN
# 2411     LWRLK   0.15   4.0  0.107  2.400000e+03         0     NaN
# 2412     PQULK   0.15   4.0  0.000  4.990000e+09         0     NaN
#
#       capacity [veh]  tt_ff [min]  speed_ff[mi/hr]  ...  median_age incidents  \
# 0             1800.0        0.098               45  ...    0.676087    0.3055
# 1             1800.0        0.169               50  ...    0.747826    0.2000
# 2             2400.0        0.396               65  ...    0.747826    0.2000
# 3             2000.0        0.192               25  ...    0.747826    0.2000
# 4             1800.0        0.105               35  ...    0.747826    0.3055
# ...              ...          ...              ...  ...         ...       ...
# 2408             inf        0.000            99999  ...    0.000000    0.0000
# 2409             inf        0.000            99999  ...    0.000000    0.0000
# 2410          1800.0        0.045               65  ...    0.628261    0.3000
# 2411          2400.0        0.107               65  ...    0.978261    0.3055
# 2412             inf        0.000            99999  ...    0.000000    0.0000
#
#       bus_stops  intersections  high_inc  low_inc  no_incidents  no_bus_stops  \
# 0       0.39175            0.3         1        0             0             0
# 1       0.39175            0.1         1        0             0             0
# 2       0.39175            0.1         1        0             0             0
# 3       0.39175            0.1         1        0             0             0
# 4       0.39175            0.1         1        0             0             0
# ...         ...            ...       ...      ...           ...           ...
# 2408    0.00000            0.0         0        0             0             0
# 2409    0.00000            0.0         0        0             0             0
# 2410    0.25000            0.2         1        0             0             0
# 2411    0.39175            0.7         0        1             0             0
# 2412    0.00000            0.0         0        0             0             0
#
#       no_intersections  tt_reliability
# 0                    0        0.391353
# 1                    0        0.431036
# 2                    0        0.459576
# 3                    0        0.410937
# 4                    0        0.459576
# ...                ...             ...
# 2408                 0        0.000000
# 2409                 0        0.000000
# 2410                 0        0.498246
# 2411                 0        0.507275
# 2412                 0        0.000000
#
# [2413 rows x 42 columns]

# %%
summary_table_links_df.describe()
# Out:
#               alpha    beta           tf             k     observed  \
# count  2.413000e+03  2413.0  2413.000000  2.413000e+03  2413.000000
# mean   1.500000e-01     4.0     0.150823  1.439305e+09     0.058433
# std    2.776133e-17     0.0     0.172458  2.261116e+09     0.234610
# min    1.500000e-01     4.0     0.000000  1.800000e+03     0.000000
# 25%    1.500000e-01     4.0     0.000000  1.800000e+03     0.000000
# 50%    1.500000e-01     4.0     0.121000  1.800000e+03     0.000000
# 75%    1.500000e-01     4.0     0.205000  4.990000e+09     0.000000
# max    1.500000e-01     4.0     2.113000  4.990000e+09     1.000000
#
#             counts  capacity [veh]  tt_ff [min]  speed_ff[mi/hr]  \
# count   141.000000          2413.0  2413.000000      2413.000000
# mean   2213.607801             inf     0.150823     28872.664318
# std     849.965115             NaN     0.172458     45293.922006
# min     111.000000          1800.0     0.000000        15.000000
# 25%    1698.000000          1800.0     0.000000        40.000000
# 50%    2101.000000          1800.0     0.121000        45.000000
# 75%    2717.000000             NaN     0.205000     99999.000000
# max    4807.000000             inf     2.113000     99999.000000
#
#            inrix_id  ...   median_age    incidents    bus_stops  \
# count  1.801000e+03  ...  2413.000000  2413.000000  2413.000000
# mean   9.195424e+08  ...     0.483083     0.215402     0.278768
# std    6.053956e+08  ...     0.323928     0.166107     0.200017
# min    1.685461e+08  ...     0.000000     0.000000     0.000000
# 25%    4.416712e+08  ...     0.000000     0.000000     0.000000
# 50%    4.498919e+08  ...     0.623913     0.305500     0.391750
# 75%    1.626673e+09  ...     0.686957     0.305500     0.391750
# max    1.626774e+09  ...     1.000000     1.000000     1.000000
#
#        intersections     high_inc      low_inc  no_incidents  no_bus_stops  \
# count    2413.000000  2413.000000  2413.000000        2413.0        2413.0
# mean        0.233857     0.501450     0.210112           0.0           0.0
# std         0.220041     0.500102     0.407472           0.0           0.0
# min         0.000000     0.000000     0.000000           0.0           0.0
# 25%         0.000000     0.000000     0.000000           0.0           0.0
# 50%         0.200000     1.000000     0.000000           0.0           0.0
# 75%         0.339300     1.000000     0.000000           0.0           0.0
# max         1.000000     1.000000     1.000000           0.0           0.0
#
#        no_intersections  tt_reliability
# count            2413.0     2413.000000
# mean                0.0        0.336415
# std                 0.0        0.229487
# min                 0.0        0.000000
# 25%                 0.0        0.000000
# 50%                 0.0        0.446549
# 75%                 0.0        0.473577
# max                 0.0        1.000000
#
# [8 rows x 40 columns]

# %% [markdown]
# ## Bilevel Estimation

# %%
utility_function = isl.estimation.UtilityFunction(
    features_Y=['tt'],
    initial_values={'tt': 0},
)

equilibrator_norefined = isl.equilibrium.LUE_Equilibrator(
    network=fresno_network,
    paths_generator=paths_generator,
    utility_function=utility_function,
    max_iters=100,
    method='fw',
    iters_fw=10,
    column_generation={'n_paths': 4,
                       'ods_coverage': 0.1,
                       'paths_selection': 4},
    path_size_correction=1
)

outer_optimizer_norefined = isl.estimation.OuterOptimizer(
    method='ngd',
    iters=1,
    eta=1e-1,
)

learner_norefined = isl.estimation.Learner(
    equilibrator=equilibrator_norefined,
    outer_optimizer=outer_optimizer_norefined,
    utility_function=utility_function,
    network=fresno_network,
    name = 'norefined'
)

equilibrator_refined = isl.equilibrium.LUE_Equilibrator(
    network=fresno_network,
    paths_generator=paths_generator,
    utility_function=utility_function,
    max_iters=100,
    method='fw',
    iters_fw=10,
    path_size_correction=1
)

outer_optimizer_refined = isl.estimation.OuterOptimizer(
    method='lm',
    # method='ngd',
    iters=1,
    # eta=5e-1,
)

learner_refined = isl.estimation.Learner(
    network=fresno_network,
    equilibrator=equilibrator_refined,
    outer_optimizer=outer_optimizer_refined,
    utility_function=utility_function,
    name = 'refined'
)

# %% [markdown]
# ### a) Benchmark predictions

# %% [markdown]
# #### Naive prediction using mean counts

# %%
mean_counts_prediction_loss, mean_count_benchmark_model \
    = isl.estimation.mean_count_prediction(counts=np.array(list(counts.values()))[:, np.newaxis])

print('\nObjective function under mean count prediction: ' + '{:,}'.format(round(mean_counts_prediction_loss, 1)))
# Out:
# Objective function under mean count prediction: 101,141,667.7

# %% [markdown]
# #### Naive prediction where travelers make equilikely choices

# %%
equilikely_prediction_loss, predicted_counts_equilikely \
    = isl.estimation.loss_counts_equilikely_choices(
    network = fresno_network,
    equilibrator=equilibrator_norefined,
    counts=fresno_network.observed_counts_vector,
    utility_function=utility_function)

print('Objective function under equilikely route choices: ' + '{:,}'.format(round(equilikely_prediction_loss, 1)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 equilikely_prediction_loss, predicted_counts_equilikely \
# ----> 2     = isl.estimation.loss_counts_equilikely_choices(
#       3     network = fresno_network,
#       4     equilibrator=equilibrator_norefined,
#       5     counts=fresno_network.counts_vector,
#       6     utility_function=utility_function)
#       8 print('Objective function under equilikely route choices: ' + '{:,}'.format(round(equilikely_prediction_loss, 1)))
#
# File ~/OneDrive/data-science/github/isuelogit/src/isuelogit/estimation.py:2763, in loss_counts_equilikely_choices(**kwargs)
#    2760 utility_function = copy.deepcopy(kwargs.pop('utility_function'))
#    2761 utility_function.values = dict.fromkeys(utility_function.features, 0)
# -> 2763 return loss_counts_uncongested_network(utility_function=utility_function, **kwargs)
#
# File ~/OneDrive/data-science/github/isuelogit/src/isuelogit/estimation.py:2748, in loss_counts_uncongested_network(equilibrator, network, counts, utility_function)
#    2745 theta = utility_function.values
#    2747 with block_output(show_stdout=False, show_stderr=False):
# -> 2748     results_uncongested_eq = equilibrator.sue_logit_iterative(theta=theta,
#    2749                                                               network=network,
#    2750                                                               features_Y=features_Y,
#    2751                                                               features_Z=features_Z,
#    2752                                                               uncongested_mode=True)
#    2754 predicted_counts = np.array(list(results_uncongested_eq['x'].values()))[:, np.newaxis]
#    2756 return loss_function(observed_counts=counts, predicted_counts=predicted_counts), predicted_counts
#
# File ~/OneDrive/data-science/github/isuelogit/src/isuelogit/equilibrium.py:407, in sue_logit_iterative(self, features_Z, theta, q, silent_mode, network, **kwargs)
#     400 if options['column_generation']['n_paths'] is not None and column_generation_done is False:
#     402     self.sue_column_generation(theta=theta,
#     403                                n_paths=options['column_generation']['n_paths'],
#     404                                ods_coverage=options['column_generation']['ods_coverage'],
#     405                                network=network
#     406                                )
# --> 407     column_generation_done = True
#     409 if options['path_size_correction'] > 0:
#     411     path_specific_utilities = []
#
# File ~/OneDrive/data-science/github/isuelogit/src/isuelogit/equilibrium.py:863, in sue_column_generation(self, network, theta, n_paths, ods_coverage, ods_sampling, silent_mode)
#     855     ods_sample = network.ods
#     857 with block_output(show_stdout=False, show_stderr=False):
#     858     paths, paths_od = self.paths_generator.k_shortest_paths(network = network,
#     859                                                             theta = theta,
#     860                                                             k = n_paths,
#     861                                                             ods = ods_sample,
#     862                                                             paths_per_od = n_paths,
# --> 863                                                             silent_mode = True)
#     865 # See if new paths were found so they are added into the existing path set
#     866 paths_added = 0
#
# File ~/OneDrive/data-science/github/isuelogit/src/isuelogit/factory.py:916, in PathsGenerator.k_shortest_paths(self, k, network, theta, ods, **kwargs)
#     913     edge_utilities = network.generate_edges_weights(V=network.V)
#     915     # Generate new paths according to arbitrary size given by n_paths
# --> 916     paths, paths_od = k_path_generation_nx(A= network.A,
#     917                                            ods= ods,
#     918                                            links= network.links_dict,
#     919                                            edge_weights = edge_utilities,
#     920                                            **kwargs
#     921                                            )
#     923 else:
#     924     # This uses the number of links for shortest paths only
#     925     paths, paths_od = k_path_generation_nx(A=network.A,
#     926                                            ods=ods,
#     927                                            links=network.links_dict,
#     928                                            **kwargs)
#
# File ~/OneDrive/data-science/github/isuelogit/src/isuelogit/paths.py:520, in k_path_generation_nx(A, ods, links, cutoff, n_paths, edge_weights, silent_mode, max_attempts, cutoff_increase_factor, **kwargs)
#     518 if edge_weights is not None:
#     519     weight = 'utility'
# --> 520     nx.set_edge_attributes(G, name=weight, values=edge_weights)
#     522 for od, counter in zip(ods, range(len(ods))):
#     523     # print(od)
#     525     printer.enablePrint()
#
# File ~/OneDrive/data-science/github/isuelogit/venv-isuelogit/lib/python3.9/site-packages/networkx/classes/function.py:801, in set_edge_attributes(G, values, name)
#     799 for (u, v), value in values.items():
#     800     try:
# --> 801         G[u][v][name] = value
#     802     except KeyError:
#     803         pass
#
# File ~/OneDrive/data-science/github/isuelogit/venv-isuelogit/lib/python3.9/site-packages/networkx/classes/graph.py:476, in Graph.__getitem__(self, n)
#     452 def __getitem__(self, n):
#     453     """Returns a dict of neighbors of node n.  Use: 'G[n]'.
#     454
#     455     Parameters
#    (...)
#     474     AtlasView({1: {}})
#     475     """
# --> 476     return self.adj[n]
#
# File ~/OneDrive/data-science/github/isuelogit/venv-isuelogit/lib/python3.9/site-packages/networkx/classes/coreviews.py:82, in AdjacencyView.__getitem__(self, name)
#      81 def __getitem__(self, name):
# ---> 82     return AtlasView(self._atlas[name])
#
# KeyboardInterrupt:

# %% [markdown]
# ### b) Model with travel time feature only

# %% [markdown]
# #### No refined stage

# %%
learning_results_norefined, inference_results_norefined, best_iter_norefined = \
    learner_norefined.statistical_inference(h0=0, bilevel_iters=10, alpha=0.05, link_report=False, iteration_report = True)

theta_norefined = learning_results_norefined[best_iter_norefined]['theta']
# Out:
# Bilevel optimization for Fresno network
#
# Iteration : 1/10
#
# Initial theta: {'tt': '0.0E+00'}
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['0E+00']
# Initial Fisk Objective: -162,069.74
# Final Fisk Objective: -162,069.74
# Improvement Fisk Objective: 0.00%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 136.5 [s]
# Initial objective: 306,738,799
# Initial RMSE: 1474.9
# Initial Normalized RMSE: 0.666
#
# Iteration : 2/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-1.0E-01'}------| 0.0%
# time: 153.1[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 158 paths added/replaced among 156 ods (New total paths: 26538)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 158 paths removed among 156 ods (New total paths: 26380)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['4E-05']
# Initial Fisk Objective: -167,329.36
# Final Fisk Objective: -166,675.51
# Improvement Fisk Objective: 0.39%
# Final gap: 4E-05. Acc. bound: 1E-04. Time: 257.4 [s]
#
# Time current iteration: 410.7 [s]
# Current objective_value: 273,550,045
# Current objective improvement: 10.82%
# Current RMSE: 1392.9
# Current Normalized RMSE: 0.629
# Marginal objective improvement: 10.82%
# Marginal objective improvement value: 33,188,753.8
#
#
# Iteration : 3/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-2.0E-01'}------| 0.0%
# time: 156.3[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 155 paths added/replaced among 151 ods (New total paths: 26535)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 155 paths removed among 151 ods (New total paths: 26380)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['3E-04', '7E-06']
# Initial Fisk Objective: -172,267.61
# Final Fisk Objective: -170,683.8
# Improvement Fisk Objective: 0.92%
# Final gap: 7E-06. Acc. bound: 1E-04. Time: 298.2 [s]
#
# Time current iteration: 454.9 [s]
# Current objective_value: 256,902,911
# Current objective improvement: 16.25%
# Current RMSE: 1349.8
# Current Normalized RMSE: 0.61
# Marginal objective improvement: 6.09%
# Marginal objective improvement value: 16,647,133.8
#
#
# Iteration : 4/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-3.0E-01'}------| 0.0%
# time: 157.1[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 144 paths added/replaced among 139 ods (New total paths: 26524)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 144 paths removed among 139 ods (New total paths: 26380)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['6E-04', '8E-06']
# Initial Fisk Objective: -176,926.2
# Final Fisk Objective: -174,407.88
# Improvement Fisk Objective: 1.42%
# Final gap: 8E-06. Acc. bound: 1E-04. Time: 267.2 [s]
#
# Time current iteration: 424.6 [s]
# Current objective_value: 245,471,551
# Current objective improvement: 19.97%
# Current RMSE: 1319.4
# Current Normalized RMSE: 0.596
# Marginal objective improvement: 4.45%
# Marginal objective improvement value: 11,431,360.1
#
#
# Iteration : 5/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-4.0E-01'}------| 0.0%
# time: 148.8[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 171 paths added/replaced among 168 ods (New total paths: 26551)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 171 paths removed among 168 ods (New total paths: 26380)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['1E-03', '0E+00']
# Initial Fisk Objective: -181,348.66
# Final Fisk Objective: -177,966.54
# Improvement Fisk Objective: 1.86%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 274.1 [s]
#
# Time current iteration: 423.2 [s]
# Current objective_value: 237,382,851
# Current objective improvement: 22.61%
# Current RMSE: 1297.5
# Current Normalized RMSE: 0.586
# Marginal objective improvement: 3.30%
# Marginal objective improvement value: 8,088,700.4
#
#
# Iteration : 6/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-5.0E-01'}------| 0.0%
# time: 145.8[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 173 paths added/replaced among 168 ods (New total paths: 26553)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 173 paths removed among 168 ods (New total paths: 26380)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['2E-03', '0E+00']
# Initial Fisk Objective: -185,556.45
# Final Fisk Objective: -181,414.0
# Improvement Fisk Objective: 2.23%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 275.8 [s]
#
# Time current iteration: 422.0 [s]
# Current objective_value: 231,589,441
# Current objective improvement: 24.50%
# Current RMSE: 1281.6
# Current Normalized RMSE: 0.579
# Marginal objective improvement: 2.44%
# Marginal objective improvement value: 5,793,409.5
#
#
# Iteration : 7/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-6.0E-01'}------| 0.0%
# time: 156.2[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 153 paths added/replaced among 146 ods (New total paths: 26533)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 153 paths removed among 146 ods (New total paths: 26380)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['2E-03', '0E+00']
# Initial Fisk Objective: -189,605.77
# Final Fisk Objective: -184,807.22
# Improvement Fisk Objective: 2.53%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 272.9 [s]
#
# Time current iteration: 429.5 [s]
# Current objective_value: 228,362,084
# Current objective improvement: 25.55%
# Current RMSE: 1272.6
# Current Normalized RMSE: 0.575
# Marginal objective improvement: 1.39%
# Marginal objective improvement value: 3,227,357.0
#
#
# Iteration : 8/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-7.0E-01'}------| 0.0%
# time: 149.7[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 164 paths added/replaced among 156 ods (New total paths: 26544)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 164 paths removed among 156 ods (New total paths: 26380)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['2E-03', '0E+00']
# Initial Fisk Objective: -193,519.78
# Final Fisk Objective: -188,158.85
# Improvement Fisk Objective: 2.77%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 270.5 [s]
#
# Time current iteration: 420.5 [s]
# Current objective_value: 225,087,862
# Current objective improvement: 26.62%
# Current RMSE: 1263.5
# Current Normalized RMSE: 0.571
# Marginal objective improvement: 1.43%
# Marginal objective improvement value: 3,274,222.5
#
#
# Iteration : 9/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-8.0E-01'}------| 0.0%
# time: 163.5[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 167 paths added/replaced among 158 ods (New total paths: 26547)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 167 paths removed among 158 ods (New total paths: 26380)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['2E-03', '0E+00']
# Initial Fisk Objective: -197,335.4
# Final Fisk Objective: -191,489.79
# Improvement Fisk Objective: 2.96%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 277.7 [s]
#
# Time current iteration: 441.6 [s]
# Current objective_value: 222,570,239
# Current objective improvement: 27.44%
# Current RMSE: 1256.4
# Current Normalized RMSE: 0.568
# Marginal objective improvement: 1.12%
# Marginal objective improvement value: 2,517,622.7
#
#
# Iteration : 10/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-9.0E-01'}------| 0.0%
# time: 149.7[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['3E-03', '0E+00']
# Initial Fisk Objective: -201,079.83
# Final Fisk Objective: -194,808.05
# Improvement Fisk Objective: 3.12%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 165.3 [s]
#
# Time current iteration: 315.4 [s]
# Current objective_value: 220,593,075
# Current objective improvement: 28.08%
# Current RMSE: 1250.8
# Current Normalized RMSE: 0.565
# Marginal objective improvement: 0.89%
# Marginal objective improvement value: 1,977,164.4
#
# Summary results of bilevel optimization
# best iter: 10
# best theta: {'tt': '-9.0E-01'}
# best objective_value: 220,593,075
# Final best objective improvement: 28.08%
# Final best objective improvement value: 86,145,724.3
# Best RMSE: 1250.8
# Best Normalized RMSE: 0.565
# Total time: 3742.5 [s]
#
# Performing hypothesis testing (H0: theta = 0, alpha = 0.05)
# Hessian approximated as J^T J
#
# Summary of parameters:
#  parameter    est               CI  width_CI  t-test  p-value
#        tt -0.900 [-1.436, -0.364]     0.536  -3.320    0.001
#
# Computing F-test
#
# Summary of model:
#       F  critical-F     p   n  dof_m1  dof_m2        sse_m1        sse_m2
# 51.888       3.909 0.000 141       0       1 301993656.245 220332378.139
# Time: 209.9[s]

# %% [markdown]
# #### Refined stage

# %%
learner_refined.utility_function.initial_values = theta_norefined

learning_results_refined, inference_results_refined, best_iter_refined = \
    learner_refined.statistical_inference(h0=0, bilevel_iters=10, alpha=0.05, link_report=False, iteration_report = True)

theta_refined = learning_results_refined[best_iter_refined]['theta']
# Out:
# Bilevel optimization for Fresno network
#
# Iteration : 1/10
#
# Initial theta: {'tt': '-9.0E-01'}
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['3E-03', '0E+00']
# Initial Fisk Objective: -201,079.83
# Final Fisk Objective: -194,808.05
# Improvement Fisk Objective: 3.12%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 163.8 [s]
# Initial objective: 220,593,075
# Initial RMSE: 1250.8
# Initial Normalized RMSE: 0.565
#
# Iteration : 2/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '-1.4E+00'}
# time: 176.1[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['4E-03', '0E+00']
# Initial Fisk Objective: -217,981.45
# Final Fisk Objective: -209,936.5
# Improvement Fisk Objective: 3.69%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 159.0 [s]
#
# Time current iteration: 335.3 [s]
# Current objective_value: 214,178,194
# Current objective improvement: 2.91%
# Current RMSE: 1232.5
# Current Normalized RMSE: 0.557
# Marginal objective improvement: 2.91%
# Marginal objective improvement value: 6,414,880.4
#
#
# Iteration : 3/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '-1.8E+00'}
# time: 180.9[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['5E-03', '0E+00']
# Initial Fisk Objective: -232,921.42
# Final Fisk Objective: -222,722.72
# Improvement Fisk Objective: 4.38%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 161.9 [s]
#
# Time current iteration: 343.0 [s]
# Current objective_value: 210,887,393
# Current objective improvement: 4.40%
# Current RMSE: 1223.0
# Current Normalized RMSE: 0.552
# Marginal objective improvement: 1.54%
# Marginal objective improvement value: 3,290,801.5
#
#
# Iteration : 4/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '-2.2E+00'}
# time: 174.4[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['4E-03', '0E+00']
# Initial Fisk Objective: -249,367.34
# Final Fisk Objective: -236,229.39
# Improvement Fisk Objective: 5.27%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 162.7 [s]
#
# Time current iteration: 337.4 [s]
# Current objective_value: 209,666,983
# Current objective improvement: 4.95%
# Current RMSE: 1219.4
# Current Normalized RMSE: 0.551
# Marginal objective improvement: 0.58%
# Marginal objective improvement value: 1,220,409.5
#
#
# Iteration : 5/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '-3.0E+00'}
# time: 180.2[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['9E-04', '0E+00']
# Initial Fisk Objective: -278,600.31
# Final Fisk Objective: -259,016.58
# Improvement Fisk Objective: 7.03%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 148.3 [s]
#
# Time current iteration: 328.7 [s]
# Current objective_value: 207,024,490
# Current objective improvement: 6.15%
# Current RMSE: 1211.7
# Current Normalized RMSE: 0.547
# Marginal objective improvement: 1.26%
# Marginal objective improvement value: 2,642,493.4
#
#
# Iteration : 6/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '-3.2E+00'}
# time: 186.4[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['5E-04', '0E+00']
# Initial Fisk Objective: -284,797.2
# Final Fisk Objective: -263,618.79
# Improvement Fisk Objective: 7.44%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 160.2 [s]
#
# Time current iteration: 346.8 [s]
# Current objective_value: 206,801,391
# Current objective improvement: 6.25%
# Current RMSE: 1211.1
# Current Normalized RMSE: 0.547
# Marginal objective improvement: 0.11%
# Marginal objective improvement value: 223,098.9
#
#
# Iteration : 7/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '-3.3E+00'}
# time: 177.6[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['5E-04', '0E+00']
# Initial Fisk Objective: -287,078.09
# Final Fisk Objective: -265,292.26
# Improvement Fisk Objective: 7.59%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 154.0 [s]
#
# Time current iteration: 331.8 [s]
# Current objective_value: 206,062,408
# Current objective improvement: 6.59%
# Current RMSE: 1208.9
# Current Normalized RMSE: 0.546
# Marginal objective improvement: 0.36%
# Marginal objective improvement value: 738,983.4
#
#
# Iteration : 8/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '-3.1E+00'}
# time: 175.4[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['7E-04', '0E+00']
# Initial Fisk Objective: -281,267.43
# Final Fisk Objective: -261,003.39
# Improvement Fisk Objective: 7.20%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 152.0 [s]
#
# Time current iteration: 327.7 [s]
# Current objective_value: 206,926,442
# Current objective improvement: 6.59%
# Current RMSE: 1211.4
# Current Normalized RMSE: 0.547
# Marginal objective improvement: -0.42%
# Marginal objective improvement value: -864,034.3
#
#
# Iteration : 9/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '-3.3E+00'}
# time: 181.3[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['5E-04', '9E-07']
# Initial Fisk Objective: -285,899.28
# Final Fisk Objective: -264,428.09
# Improvement Fisk Objective: 7.51%
# Final gap: 9E-07. Acc. bound: 1E-04. Time: 153.7 [s]
#
# Time current iteration: 335.2 [s]
# Current objective_value: 206,542,764
# Current objective improvement: 6.59%
# Current RMSE: 1210.3
# Current Normalized RMSE: 0.547
# Marginal objective improvement: 0.19%
# Marginal objective improvement value: 383,678.4
#
#
# Iteration : 10/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '-3.2E+00'}
# time: 176.9[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['5E-04', '5E-06']
# Initial Fisk Objective: -285,415.16
# Final Fisk Objective: -264,071.95
# Improvement Fisk Objective: 7.48%
# Final gap: 5E-06. Acc. bound: 1E-04. Time: 153.6 [s]
#
# Time current iteration: 330.7 [s]
# Current objective_value: 206,561,925
# Current objective improvement: 6.59%
# Current RMSE: 1210.4
# Current Normalized RMSE: 0.547
# Marginal objective improvement: -0.01%
# Marginal objective improvement value: -19,161.1
#
# Summary results of bilevel optimization
# best iter: 7
# best theta: {'tt': '-3.3E+00'}
# best objective_value: 206,062,408
# Final best objective improvement: 6.59%
# Final best objective improvement value: 14,530,667.0
# Best RMSE: 1208.9
# Best Normalized RMSE: 0.546
# Total time: 3016.6 [s]
#
# Performing hypothesis testing (H0: theta = 0, alpha = 0.05)
# Hessian approximated as J^T J
#
# Summary of parameters:
#  parameter    est              CI  width_CI  t-test  p-value
#        tt -3.290 [-6.992, 0.411]     3.701  -1.758    0.081
#
# Computing F-test
#
# Summary of model:
#       F  critical-F     p   n  dof_m1  dof_m2        sse_m1        sse_m2
# 58.707       3.909 0.000 141       0       1 301993656.245 212770648.565
# Time: 202.5[s]

# %% [markdown]
# #### Report

# %%
estimation_reporter.add_items_report(
    selected_date = data_reader.options['selected_date'],
    selected_hour = data_reader.options['selected_hour'],
    selected_od_periods = data_reader.options['od_periods'],
    mean_counts=round(mean_count_benchmark_model,1),
    mean_counts_prediction_loss = round(mean_counts_prediction_loss,1),
    equilikely_prediction_loss = round(equilikely_prediction_loss,1)
)

estimation_reporter.add_items_report(
    theta_norefined=theta_norefined,
    theta_refined= theta_refined,
    best_objective_norefined = round(learning_results_norefined[best_iter_norefined]['objective'],1),
    best_objective_refined = round(learning_results_refined[best_iter_refined]['objective'],1),
)

# Summary with most relevant options, prediction error, initial parameters, etc
estimation_reporter.write_estimation_report(
    network=fresno_network,
    learners=[learner_norefined, learner_refined],
    utility_function=utility_function)

# Write tables with results on learning and inference
estimation_reporter.write_learning_tables(
    results_norefined=learning_results_norefined,
    results_refined=learning_results_refined,
    network = fresno_network,
    utility_function = utility_function)

estimation_reporter.write_inference_tables(
    results_norefined=inference_results_norefined,
    results_refined=inference_results_refined,
    float_format = '%.3f')

# %% [markdown]
# #### Visualizations

# %% [markdown]
# ##### Convergence

# %%
results_df = isl.descriptive_statistics \
    .get_loss_and_estimates_over_iterations(results_norefined=learning_results_norefined
                                            , results_refined=learning_results_refined)

fig = isl.visualization.Artist().convergence(
    results_norefined_df=results_df[results_df['stage'] == 'norefined'],
    results_refined_df=results_df[results_df['stage'] == 'refined'],
    filename='convergence_' + fresno_network.key,
    methods=[outer_optimizer_norefined.method.key, outer_optimizer_refined.method.key],
    folder = estimation_reporter.dirs['estimation_folder'],
    simulated_data = False
)

# %% [markdown]
# ##### Distribution of errors across link counts

# %%
best_predicted_counts_norefined = np.array(list(learning_results_norefined[best_iter_norefined]['x'].values()))[:, np.newaxis]
best_predicted_counts_refined = np.array(list(learning_results_refined[best_iter_refined]['x'].values()))[:, np.newaxis]

fig, axs = plt.subplots(1, 2, sharey='all', tight_layout=True, figsize=(8, 4))

axs[0].hist(isl.estimation.error_by_link(observed_counts=np.array(list(counts.values()))[:, np.newaxis],
                                         predicted_counts=best_predicted_counts_norefined))
axs[1].hist(isl.estimation.error_by_link(observed_counts=np.array(list(counts.values()))[:, np.newaxis],
                                         predicted_counts=best_predicted_counts_refined))

for axi in [axs[0], axs[1]]:
    axi.tick_params(axis='x', labelsize=16)
    axi.tick_params(axis='y', labelsize=16)

plt.show()

fig.savefig(estimation_reporter.dirs['estimation_folder'] + '/' + 'distribution_predicted_error_counts.pdf',
            pad_inches=0.1, bbox_inches="tight")

# %% [markdown]
# ### c) Model with all features

# %%
utility_function_full_model = isl.estimation.UtilityFunction(
    features_Y=['tt'],
    features_Z= ['tt_cv', 'incidents', 'intersections', 'bus_stops', 'median_inc'],
    signs = {'tt': '-', 'tt_cv':'-', 'incidents':'-', 'intersections':'-', 'bus_stops':'-', 'median_inc':'+'}
)

# Update utility functions of no refined and refined learners
learner_norefined.utility_function = utility_function_full_model
learner_refined.utility_function = utility_function_full_model

#Initialize value with the estimate obtained from b)
learner_norefined.utility_function.initial_values = theta_refined

estimation_reporter = isl.writer.Reporter(
    folderpath = isl.config.dirs['output_folder'] + 'estimations/' + network_name, seed =_SEED)

# %% [markdown]
# #### No refined stage

# %%
learning_results_norefined, inference_results_norefined, best_iter_norefined = \
    learner_norefined.statistical_inference(h0=0, bilevel_iters=10, alpha=0.05, link_report=False, iteration_report = True)

theta_norefined_full_model = learning_results_norefined[best_iter_norefined]['theta']
# Out:
# Bilevel optimization for Fresno network
#
# Iteration : 1/10
#
# Initial theta: {'tt': '-3.3E+00', 'tt_cv': '0.0E+00', 'incidents': '0.0E+00', 'intersections': '0.0E+00', 'bus_stops': '0.0E+00', 'median_inc': '0.0E+00'}
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['5E-04', '0E+00']
# Initial Fisk Objective: -287,078.09
# Final Fisk Objective: -265,292.26
# Improvement Fisk Objective: 7.59%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 164.4 [s]
# Initial objective: 206,062,408
# Initial RMSE: 1208.9
# Initial Normalized RMSE: 0.546
#
# Iteration : 2/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-3.3E+00', 'tt_cv': '5.4E-02', 'incidents': '1.7E-02', 'intersections': '2.9E-02', 'bus_stops': '4.6E-02', 'median_inc': '6.2E-02'}
# time: 785.5[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 1397 paths added/replaced among 697 ods (New total paths: 27777)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 3 paths removed among 3 ods (New total paths: 27774)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['2E-02', '0E+00']
# Initial Fisk Objective: -112,587.72
# Final Fisk Objective: -90,408.87
# Improvement Fisk Objective: 19.70%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 325.0 [s]
#
# Time current iteration: 1110.9 [s]
# Current objective_value: 204,685,789
# Current objective improvement: 0.67%
# Current RMSE: 1204.9
# Current Normalized RMSE: 0.544
# Marginal objective improvement: 0.67%
# Marginal objective improvement value: 1,376,618.7
#
#
# Iteration : 3/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-3.3E+00', 'tt_cv': '1.1E-01', 'incidents': '3.1E-02', 'intersections': '5.6E-02', 'bus_stops': '9.1E-02', 'median_inc': '1.2E-01'}
# time: 980.5[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 765 paths added/replaced among 527 ods (New total paths: 28539)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 765 paths removed among 527 ods (New total paths: 27774)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['3E-02', '0E+00']
# Initial Fisk Objective: 61,546.72
# Final Fisk Objective: 78,662.85
# Improvement Fisk Objective: 27.81%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 316.4 [s]
#
# Time current iteration: 1297.3 [s]
# Current objective_value: 212,588,745
# Current objective improvement: 0.67%
# Current RMSE: 1227.9
# Current Normalized RMSE: 0.555
# Marginal objective improvement: -3.86%
# Marginal objective improvement value: -7,902,956.2
#
#
# Iteration : 4/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-3.3E+00', 'tt_cv': '1.7E-01', 'incidents': '6.1E-02', 'intersections': '8.8E-02', 'bus_stops': '1.4E-01', 'median_inc': '1.8E-01'}
# time: 952.2[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 162 paths added/replaced among 159 ods (New total paths: 27936)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 162 paths removed among 159 ods (New total paths: 27774)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['4E-03', '1E-03', '0E+00']
# Initial Fisk Objective: 258,217.36
# Final Fisk Objective: 287,743.57
# Improvement Fisk Objective: 11.43%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 364.0 [s]
#
# Time current iteration: 1316.6 [s]
# Current objective_value: 211,620,622
# Current objective improvement: 0.67%
# Current RMSE: 1225.1
# Current Normalized RMSE: 0.553
# Marginal objective improvement: 0.46%
# Marginal objective improvement value: 968,123.6
#
#
# Iteration : 5/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-3.3E+00', 'tt_cv': '2.2E-01', 'incidents': '8.8E-02', 'intersections': '1.3E-01', 'bus_stops': '1.8E-01', 'median_inc': '2.4E-01'}
# time: 963.7[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 163 paths added/replaced among 157 ods (New total paths: 27937)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 163 paths removed among 157 ods (New total paths: 27774)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['3E-03', '4E-04', '4E-04', '7E-04', '0E+00']
# Initial Fisk Objective: 437,167.88
# Final Fisk Objective: 503,599.82
# Improvement Fisk Objective: 15.20%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 447.6 [s]
#
# Time current iteration: 1411.7 [s]
# Current objective_value: 209,202,775
# Current objective improvement: 0.67%
# Current RMSE: 1218.1
# Current Normalized RMSE: 0.55
# Marginal objective improvement: 1.14%
# Marginal objective improvement value: 2,417,846.4
#
#
# Iteration : 6/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-3.3E+00', 'tt_cv': '2.3E-01', 'incidents': '8.6E-02', 'intersections': '1.7E-01', 'bus_stops': '2.3E-01', 'median_inc': '3.1E-01'}
# time: 940.2[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 151 paths added/replaced among 147 ods (New total paths: 27925)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 151 paths removed among 147 ods (New total paths: 27774)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['3E-03', '1E-03', '3E-03', '0E+00']
# Initial Fisk Objective: 591,236.34
# Final Fisk Objective: 691,268.62
# Improvement Fisk Objective: 16.92%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 398.8 [s]
#
# Time current iteration: 1339.4 [s]
# Current objective_value: 208,256,441
# Current objective improvement: 0.67%
# Current RMSE: 1215.3
# Current Normalized RMSE: 0.549
# Marginal objective improvement: 0.45%
# Marginal objective improvement value: 946,334.5
#
#
# Iteration : 7/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-3.3E+00', 'tt_cv': '1.7E-01', 'incidents': '3.1E-02', 'intersections': '1.6E-01', 'bus_stops': '1.9E-01', 'median_inc': '2.8E-01'}
# time: 1005.1[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 190 paths added/replaced among 186 ods (New total paths: 27964)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 190 paths removed among 186 ods (New total paths: 27774)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['2E-03', '2E-04', '1E-04', '2E-04', '2E-04', '8E-05']
# Initial Fisk Objective: 441,951.99
# Final Fisk Objective: 501,871.83
# Improvement Fisk Objective: 13.56%
# Final gap: 8E-05. Acc. bound: 1E-04. Time: 499.9 [s]
#
# Time current iteration: 1505.4 [s]
# Current objective_value: 209,140,771
# Current objective improvement: 0.67%
# Current RMSE: 1217.9
# Current Normalized RMSE: 0.55
# Marginal objective improvement: -0.42%
# Marginal objective improvement value: -884,329.9
#
#
# Iteration : 8/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-3.3E+00', 'tt_cv': '2.1E-01', 'incidents': '4.2E-02', 'intersections': '2.0E-01', 'bus_stops': '2.4E-01', 'median_inc': '3.4E-01'}
# time: 999.4[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 191 paths added/replaced among 183 ods (New total paths: 27965)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 191 paths removed among 183 ods (New total paths: 27774)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['3E-03', '9E-04', '3E-03', '0E+00']
# Initial Fisk Objective: 608,851.17
# Final Fisk Objective: 708,089.04
# Improvement Fisk Objective: 16.30%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 416.4 [s]
#
# Time current iteration: 1416.2 [s]
# Current objective_value: 207,051,380
# Current objective improvement: 0.67%
# Current RMSE: 1211.8
# Current Normalized RMSE: 0.547
# Marginal objective improvement: 1.00%
# Marginal objective improvement value: 2,089,390.3
#
#
# Iteration : 9/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-3.3E+00', 'tt_cv': '1.5E-01', 'incidents': '-6.2E-03', 'intersections': '1.8E-01', 'bus_stops': '2.0E-01', 'median_inc': '3.0E-01'}
# time: 958.0[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 171 paths added/replaced among 162 ods (New total paths: 27945)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 171 paths removed among 162 ods (New total paths: 27774)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['2E-03', '5E-05']
# Initial Fisk Objective: 446,368.34
# Final Fisk Objective: 503,514.14
# Improvement Fisk Objective: 12.80%
# Final gap: 5E-05. Acc. bound: 1E-04. Time: 312.1 [s]
#
# Time current iteration: 1270.5 [s]
# Current objective_value: 213,872,301
# Current objective improvement: 0.67%
# Current RMSE: 1231.6
# Current Normalized RMSE: 0.556
# Marginal objective improvement: -3.29%
# Marginal objective improvement value: -6,820,920.3
#
#
# Iteration : 10/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-3.3E+00', 'tt_cv': '2.0E-01', 'incidents': '1.8E-02', 'intersections': '2.2E-01', 'bus_stops': '2.5E-01', 'median_inc': '3.6E-01'}
# time: 976.3[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['3E-03', '8E-04', '3E-03', '0E+00']
# Initial Fisk Objective: 618,332.84
# Final Fisk Objective: 717,571.76
# Improvement Fisk Objective: 16.05%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 294.1 [s]
#
# Time current iteration: 1270.7 [s]
# Current objective_value: 207,045,384
# Current objective improvement: 0.67%
# Current RMSE: 1211.8
# Current Normalized RMSE: 0.547
# Marginal objective improvement: 3.19%
# Marginal objective improvement value: 6,826,916.3
#
# Summary results of bilevel optimization
# best iter: 2
# best theta: {'tt': '-3.3E+00', 'tt_cv': '5.4E-02', 'incidents': '1.7E-02', 'intersections': '2.9E-02', 'bus_stops': '4.6E-02', 'median_inc': '6.2E-02'}
# best objective_value: 204,685,789
# Final best objective improvement: 0.67%
# Final best objective improvement value: 1,376,618.7
# Best RMSE: 1204.9
# Best Normalized RMSE: 0.544
# Total time: 11939.0 [s]
#
# Performing hypothesis testing (H0: theta = 0, alpha = 0.05)
# Hessian approximated as J^T J
#
# Summary of parameters:
#      parameter    est              CI  width_CI  t-test  p-value
#            tt -3.290 [-9.732, 3.152]     6.442  -1.010    0.314
#         tt_cv  0.054 [-1.219, 1.328]     1.273   0.085    0.933
#     incidents  0.017 [-1.805, 1.838]     1.821   0.018    0.986
# intersections  0.029 [-1.924, 1.982]     1.953   0.030    0.976
#     bus_stops  0.046 [-3.871, 3.963]     3.917   0.023    0.982
#    median_inc  0.062  [-1.33, 1.454]     1.392   0.088    0.930
#
# Computing F-test
#
# Summary of model:
#      F  critical-F     p   n  dof_m1  dof_m2        sse_m1        sse_m2
# 8.004       2.166 0.000 141       0       6 305198441.791 225114931.572
# Time: 1268.7[s]

# %% [markdown]
# #### Refined stage

# %%
learner_refined.utility_function.initial_values = theta_norefined_full_model

learning_results_refined, inference_results_refined, best_iter_refined = \
    learner_refined.statistical_inference(h0=0, bilevel_iters=10, alpha=0.05, link_report=False, iteration_report = True)

theta_refined_full_model = learning_results_refined[best_iter_refined]['theta']
# Out:
# Bilevel optimization for Fresno network
#
# Iteration : 1/10
#
# Initial theta: {'tt': '-3.3E+00', 'tt_cv': '5.4E-02', 'incidents': '1.7E-02', 'intersections': '2.9E-02', 'bus_stops': '4.6E-02', 'median_inc': '6.2E-02'}
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['4E-03', '0E+00']
# Initial Fisk Objective: -120,192.15
# Final Fisk Objective: -104,265.98
# Improvement Fisk Objective: 13.25%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 193.5 [s]
# Initial objective: 218,290,691
# Initial RMSE: 1244.3
# Initial Normalized RMSE: 0.562
#
# Iteration : 2/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '-8.2E+00', 'tt_cv': '-1.1E+00', 'incidents': '-5.1E-01', 'intersections': '1.1E+00', 'bus_stops': '4.1E+00', 'median_inc': '-8.6E-02'}
# time: 1009.8[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['5E-03', '7E-03', '1E-03', '0E+00']
# Initial Fisk Objective: 1,754,918.92
# Final Fisk Objective: 2,394,298.77
# Improvement Fisk Objective: 36.43%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 308.5 [s]
#
# Time current iteration: 1318.5 [s]
# Current objective_value: 205,274,213
# Current objective improvement: 5.96%
# Current RMSE: 1206.6
# Current Normalized RMSE: 0.545
# Marginal objective improvement: 5.96%
# Marginal objective improvement value: 13,016,478.2
#
#
# Iteration : 3/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '2.9E+00', 'tt_cv': '5.6E-01', 'incidents': '-5.5E-01', 'intersections': '-2.6E+00', 'bus_stops': '-1.2E+00', 'median_inc': '8.2E-01'}
# time: 1070.5[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['4E-01', '7E-01', '1E-02', '5E-04', '4E-03', '4E-03', '2E-03', '7E-04', '2E-04', '3E-04', '0E+00']
# Initial Fisk Objective: -1,287,224.17
# Final Fisk Objective: -487,957.81
# Improvement Fisk Objective: 62.09%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 662.7 [s]
#
# Time current iteration: 1733.5 [s]
# Current objective_value: 671,131,394
# Current objective improvement: 5.96%
# Current RMSE: 2181.7
# Current Normalized RMSE: 0.986
# Marginal objective improvement: -226.94%
# Marginal objective improvement value: -465,857,181.0
#
#
# Iteration : 4/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '-2.8E+01', 'tt_cv': '-1.6E+00', 'incidents': '4.6E-01', 'intersections': '1.2E+01', 'bus_stops': '8.6E+00', 'median_inc': '-1.1E+00'}
# time: 1118.5[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['6E-03', '6E-03', '2E-03', '1E-03', '1E-03', '1E-03', '0E+00']
# Initial Fisk Objective: 10,827,749.5
# Final Fisk Objective: 12,817,190.54
# Improvement Fisk Objective: 18.37%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 437.3 [s]
#
# Time current iteration: 1556.0 [s]
# Current objective_value: 219,180,965
# Current objective improvement: 5.96%
# Current RMSE: 1246.8
# Current Normalized RMSE: 0.563
# Marginal objective improvement: 67.34%
# Marginal objective improvement value: 451,950,428.2
#
#
# Iteration : 5/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '-8.7E+01', 'tt_cv': '-5.1E+00', 'incidents': '-4.3E+00', 'intersections': '3.9E+01', 'bus_stops': '3.5E+01', 'median_inc': '-7.1E+00'}
# time: 1181.0[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['3E-03', '7E-03', '5E-03', '0E+00']
# Initial Fisk Objective: 30,541,271.06
# Final Fisk Objective: 39,269,359.63
# Improvement Fisk Objective: 28.58%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 302.2 [s]
#
# Time current iteration: 1483.5 [s]
# Current objective_value: 222,855,609
# Current objective improvement: 5.96%
# Current RMSE: 1257.2
# Current Normalized RMSE: 0.568
# Marginal objective improvement: -1.68%
# Marginal objective improvement value: -3,674,644.1
#
#
# Iteration : 6/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '-2.0E+03', 'tt_cv': '-1.0E+02', 'incidents': '-8.8E+01', 'intersections': '8.5E+02', 'bus_stops': '7.5E+02', 'median_inc': '-1.5E+02'}
# time: 1199.6[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['8E-03', '8E-03', '1E-03', '2E-03', '8E-04', '0E+00']
# Initial Fisk Objective: 675,710,325.93
# Final Fisk Objective: 874,719,678.51
# Improvement Fisk Objective: 29.45%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 427.2 [s]
#
# Time current iteration: 1627.1 [s]
# Current objective_value: 214,624,597
# Current objective improvement: 5.96%
# Current RMSE: 1233.8
# Current Normalized RMSE: 0.557
# Marginal objective improvement: 3.69%
# Marginal objective improvement value: 8,231,012.9
#
#
# Iteration : 7/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '9.8E+02', 'tt_cv': '2.3E+03', 'incidents': '2.3E+03', 'intersections': '-1.9E+03', 'bus_stops': '1.2E+04', 'median_inc': '-3.7E+03'}
# time: 859.9[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['2E-04', '6E-06']
# Initial Fisk Objective: 9,901,790,190.19
# Final Fisk Objective: 9,955,517,883.7
# Improvement Fisk Objective: 0.54%
# Final gap: 6E-06. Acc. bound: 1E-04. Time: 222.8 [s]
#
# Time current iteration: 1082.9 [s]
# Current objective_value: 586,088,686
# Current objective improvement: 5.96%
# Current RMSE: 2038.8
# Current Normalized RMSE: 0.921
# Marginal objective improvement: -173.08%
# Marginal objective improvement value: -371,464,089.4
#
#
# Iteration : 8/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '-1.0E+03', 'tt_cv': '4.5E+03', 'incidents': '3.0E+03', 'intersections': '-6.6E+01', 'bus_stops': '1.2E+04', 'median_inc': '-2.4E+03'}
# time: 640.7[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['5E-05']
# Initial Fisk Objective: 15,723,364,857.73
# Final Fisk Objective: 15,730,942,942.07
# Improvement Fisk Objective: 0.05%
# Final gap: 5E-05. Acc. bound: 1E-04. Time: 156.9 [s]
#
# Time current iteration: 797.9 [s]
# Current objective_value: 452,795,405
# Current objective improvement: 5.96%
# Current RMSE: 1792.0
# Current Normalized RMSE: 0.81
# Marginal objective improvement: 22.74%
# Marginal objective improvement value: 133,293,281.4
#
#
# Iteration : 9/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '-3.1E+03', 'tt_cv': '5.1E+03', 'incidents': '2.5E+03', 'intersections': '1.3E+02', 'bus_stops': '1.2E+04', 'median_inc': '-1.9E+03'}
# time: 630.9[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['2E-03', '5E-05']
# Initial Fisk Objective: 16,461,108,959.92
# Final Fisk Objective: 16,523,174,061.45
# Improvement Fisk Objective: 0.38%
# Final gap: 5E-05. Acc. bound: 1E-04. Time: 206.5 [s]
#
# Time current iteration: 837.6 [s]
# Current objective_value: 386,829,372
# Current objective improvement: 5.96%
# Current RMSE: 1656.3
# Current Normalized RMSE: 0.748
# Marginal objective improvement: 14.57%
# Marginal objective improvement value: 65,966,032.5
#
#
# Iteration : 10/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '-3.1E+03', 'tt_cv': '5.1E+03', 'incidents': '2.5E+03', 'intersections': '1.3E+02', 'bus_stops': '1.2E+04', 'median_inc': '-1.9E+03'}
# time: 606.6[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['2E-03', '5E-05']
# Initial Fisk Objective: 16,459,358,486.64
# Final Fisk Objective: 16,521,609,758.24
# Improvement Fisk Objective: 0.38%
# Final gap: 5E-05. Acc. bound: 1E-04. Time: 206.1 [s]
#
# Time current iteration: 812.9 [s]
# Current objective_value: 386,803,918
# Current objective improvement: 5.96%
# Current RMSE: 1656.3
# Current Normalized RMSE: 0.748
# Marginal objective improvement: 0.01%
# Marginal objective improvement value: 25,453.7
#
# Summary results of bilevel optimization
# best iter: 2
# best theta: {'tt': '-8.2E+00', 'tt_cv': '-1.1E+00', 'incidents': '-5.1E-01', 'intersections': '1.1E+00', 'bus_stops': '4.1E+00', 'median_inc': '-8.6E-02'}
# best objective_value: 205,274,213
# Final best objective improvement: 5.96%
# Final best objective improvement value: 13,016,478.2
# Best RMSE: 1206.6
# Best Normalized RMSE: 0.545
# Total time: 11250.0 [s]
#
# Performing hypothesis testing (H0: theta = 0, alpha = 0.05)
# Hessian approximated as J^T J
#
# Summary of parameters:
#      parameter    est                CI  width_CI  t-test  p-value
#            tt -8.189 [-27.328, 10.949]    19.139  -0.846    0.399
#         tt_cv -1.100   [-3.681, 1.481]     2.581  -0.843    0.401
#     incidents -0.506    [-3.08, 2.068]     2.574  -0.389    0.698
# intersections  1.131   [-4.382, 6.644]     5.513   0.406    0.686
#     bus_stops  4.057    [-6.6, 14.714]    10.657   0.753    0.453
#    median_inc -0.086    [-1.923, 1.75]     1.836  -0.093    0.926
#
# Computing F-test
#
# Summary of model:
#       F  critical-F     p   n  dof_m1  dof_m2        sse_m1        sse_m2
# 10.485       2.166 0.000 141       0       6 305198441.791 208181915.503
# Time: 1261.7[s]

# %% [markdown]
# #### Report

# %%
estimation_reporter.add_items_report(
    selected_date = data_reader.options['selected_date'],
    selected_hour = data_reader.options['selected_hour'],
    selected_od_periods = data_reader.options['od_periods'],
    mean_counts=round(mean_count_benchmark_model,1),
    mean_counts_prediction_loss = round(mean_counts_prediction_loss,1),
    equilikely_prediction_loss = round(equilikely_prediction_loss,1)
)

estimation_reporter.add_items_report(
    theta_norefined=theta_norefined_full_model,
    theta_refined= theta_refined_full_model,
    best_objective_norefined = round(learning_results_norefined[best_iter_norefined]['objective'],1),
    best_objective_refined = round(learning_results_refined[best_iter_refined]['objective'],1),
)

estimation_reporter.write_estimation_report(
    network=fresno_network,
    learners=[learner_norefined, learner_refined],
    utility_function=utility_function_full_model)

estimation_reporter.write_learning_tables(
    results_norefined=learning_results_norefined,
    results_refined=learning_results_refined,
    network = fresno_network,
    utility_function = utility_function_full_model)

estimation_reporter.write_inference_tables(
    results_norefined=inference_results_norefined,
    results_refined=inference_results_refined,
    float_format = '%.3f')

# %% [markdown]
# ### d) Model including features with parameters with expected sign

# %%
features_Y,features_Z = isl.estimation.feature_selection(utility_function_full_model,
                                                          theta = theta_refined_full_model,
                                                          criterion = 'sign')

utility_function_feature_selection_model = isl.estimation.UtilityFunction(
    features_Y = features_Y,
    features_Z = features_Z
)

learner_norefined.utility_function = utility_function_feature_selection_model
learner_refined.utility_function = utility_function_feature_selection_model

learner_norefined.utility_function.initial_values = theta_refined_full_model

estimation_reporter = isl.writer.Reporter(
    folderpath = isl.config.dirs['output_folder'] + 'estimations/' + network_name, seed = _SEED)

# %% [markdown]
# #### No refined stage

# %%
learning_results_norefined, inference_results_norefined, best_iter_norefined = \
    learner_norefined.statistical_inference(h0=0, bilevel_iters=10, alpha=0.05, 
                                            link_report=False, iteration_report = True)

theta_norefined_feature_selection_model = learning_results_norefined[best_iter_norefined]['theta']
# Out:
# Bilevel optimization for Fresno network
#
# Iteration : 1/10
#
# Initial theta: {'tt': '-8.2E+00', 'tt_cv': '-1.1E+00', 'incidents': '-5.1E-01'}
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['2E-04', '0E+00']
# Initial Fisk Objective: -1,453,987.86
# Final Fisk Objective: -1,411,547.58
# Improvement Fisk Objective: 2.92%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 203.9 [s]
# Initial objective: 242,913,398
# Initial RMSE: 1312.6
# Initial Normalized RMSE: 0.593
#
# Iteration : 2/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-8.2E+00', 'tt_cv': '-1.0E+00', 'incidents': '-4.6E-01'}
# time: 585.0[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 192 paths added/replaced among 178 ods (New total paths: 27966)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 192 paths removed among 178 ods (New total paths: 27774)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['2E-04', '0E+00']
# Initial Fisk Objective: -1,369,557.82
# Final Fisk Objective: -1,325,675.3
# Improvement Fisk Objective: 3.20%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 332.3 [s]
#
# Time current iteration: 917.7 [s]
# Current objective_value: 241,097,575
# Current objective improvement: 0.75%
# Current RMSE: 1307.6
# Current Normalized RMSE: 0.591
# Marginal objective improvement: 0.75%
# Marginal objective improvement value: 1,815,823.5
#
#
# Iteration : 3/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-8.2E+00', 'tt_cv': '-9.3E-01', 'incidents': '-4.1E-01'}
# time: 610.1[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 186 paths added/replaced among 176 ods (New total paths: 27960)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 186 paths removed among 176 ods (New total paths: 27774)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['1E-04', '0E+00']
# Initial Fisk Objective: -1,284,745.8
# Final Fisk Objective: -1,239,440.98
# Improvement Fisk Objective: 3.53%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 322.7 [s]
#
# Time current iteration: 933.2 [s]
# Current objective_value: 237,732,266
# Current objective improvement: 2.13%
# Current RMSE: 1298.5
# Current Normalized RMSE: 0.587
# Marginal objective improvement: 1.40%
# Marginal objective improvement value: 3,365,308.8
#
#
# Iteration : 4/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-8.2E+00', 'tt_cv': '-8.4E-01', 'incidents': '-3.5E-01'}
# time: 554.8[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 65 paths added/replaced among 64 ods (New total paths: 27839)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 65 paths removed among 64 ods (New total paths: 27774)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['9E-05']
# Initial Fisk Objective: -1,199,513.22
# Final Fisk Objective: -1,152,766.68
# Improvement Fisk Objective: 3.90%
# Final gap: 9E-05. Acc. bound: 1E-04. Time: 278.8 [s]
#
# Time current iteration: 834.0 [s]
# Current objective_value: 235,866,045
# Current objective improvement: 2.90%
# Current RMSE: 1293.4
# Current Normalized RMSE: 0.584
# Marginal objective improvement: 0.79%
# Marginal objective improvement value: 1,866,221.4
#
#
# Iteration : 5/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-8.2E+00', 'tt_cv': '-7.6E-01', 'incidents': '-3.0E-01'}
# time: 527.0[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 740 paths added/replaced among 529 ods (New total paths: 28514)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 740 paths removed among 529 ods (New total paths: 27774)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['1E-03', '0E+00']
# Initial Fisk Objective: -1,110,886.25
# Final Fisk Objective: -1,061,706.74
# Improvement Fisk Objective: 4.43%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 323.0 [s]
#
# Time current iteration: 850.4 [s]
# Current objective_value: 237,004,713
# Current objective improvement: 2.90%
# Current RMSE: 1296.5
# Current Normalized RMSE: 0.586
# Marginal objective improvement: -0.48%
# Marginal objective improvement value: -1,138,668.2
#
#
# Iteration : 6/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-8.2E+00', 'tt_cv': '-6.7E-01', 'incidents': '-2.5E-01'}
# time: 551.8[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 169 paths added/replaced among 167 ods (New total paths: 27943)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 169 paths removed among 167 ods (New total paths: 27774)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['8E-04', '0E+00']
# Initial Fisk Objective: -1,025,003.02
# Final Fisk Objective: -974,014.8
# Improvement Fisk Objective: 4.97%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 312.4 [s]
#
# Time current iteration: 864.7 [s]
# Current objective_value: 232,974,378
# Current objective improvement: 4.09%
# Current RMSE: 1285.4
# Current Normalized RMSE: 0.581
# Marginal objective improvement: 1.70%
# Marginal objective improvement value: 4,030,335.0
#
#
# Iteration : 7/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-8.2E+00', 'tt_cv': '-5.9E-01', 'incidents': '-1.9E-01'}
# time: 558.8[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 166 paths added/replaced among 158 ods (New total paths: 27940)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 166 paths removed among 158 ods (New total paths: 27774)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['7E-04', '0E+00']
# Initial Fisk Objective: -939,113.75
# Final Fisk Objective: -886,804.62
# Improvement Fisk Objective: 5.57%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 317.1 [s]
#
# Time current iteration: 876.4 [s]
# Current objective_value: 231,137,524
# Current objective improvement: 4.85%
# Current RMSE: 1280.3
# Current Normalized RMSE: 0.578
# Marginal objective improvement: 0.79%
# Marginal objective improvement value: 1,836,853.8
#
#
# Iteration : 8/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-8.2E+00', 'tt_cv': '-5.1E-01', 'incidents': '-1.3E-01'}
# time: 580.3[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 150 paths added/replaced among 146 ods (New total paths: 27924)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 150 paths removed among 146 ods (New total paths: 27774)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['5E-04', '0E+00']
# Initial Fisk Objective: -852,616.64
# Final Fisk Objective: -798,990.55
# Improvement Fisk Objective: 6.29%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 317.1 [s]
#
# Time current iteration: 897.7 [s]
# Current objective_value: 229,387,251
# Current objective improvement: 5.57%
# Current RMSE: 1275.5
# Current Normalized RMSE: 0.576
# Marginal objective improvement: 0.76%
# Marginal objective improvement value: 1,750,273.2
#
#
# Iteration : 9/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-8.2E+00', 'tt_cv': '-4.3E-01', 'incidents': '-7.6E-02'}
# time: 576.4[s]
#
# SUE via fw (max iters: 100)
#
# Column generation: 4 paths per od, 10.0% od coverage, demand sampling
# 175 paths added/replaced among 170 ods (New total paths: 27949)
# Performed path size correction with factor 1
#
# Path selection: dissimilarity_weight: 0, paths per od: 4
# 175 paths removed among 170 ods (New total paths: 27774)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['3E-04', '0E+00']
# Initial Fisk Objective: -766,086.88
# Final Fisk Objective: -711,029.26
# Improvement Fisk Objective: 7.19%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 319.1 [s]
#
# Time current iteration: 895.8 [s]
# Current objective_value: 225,535,749
# Current objective improvement: 7.15%
# Current RMSE: 1264.7
# Current Normalized RMSE: 0.571
# Marginal objective improvement: 1.68%
# Marginal objective improvement value: 3,851,502.0
#
#
# Iteration : 10/10
#
# Learning params via ngd (1 iters, eta = 1.0E-01)
#
# theta: {'tt': '-8.2E+00', 'tt_cv': '-3.4E-01', 'incidents': '-2.2E-02'}
# time: 551.1[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['2E-04', '0E+00']
# Initial Fisk Objective: -679,299.18
# Final Fisk Objective: -622,732.76
# Improvement Fisk Objective: 8.33%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 196.9 [s]
#
# Time current iteration: 748.4 [s]
# Current objective_value: 223,699,396
# Current objective improvement: 7.91%
# Current RMSE: 1259.6
# Current Normalized RMSE: 0.569
# Marginal objective improvement: 0.81%
# Marginal objective improvement value: 1,836,353.4
#
# Summary results of bilevel optimization
# best iter: 10
# best theta: {'tt': '-8.2E+00', 'tt_cv': '-3.4E-01', 'incidents': '-2.2E-02'}
# best objective_value: 223,699,396
# Final best objective improvement: 7.91%
# Final best objective improvement value: 19,214,002.8
# Best RMSE: 1259.6
# Best Normalized RMSE: 0.569
# Total time: 7818.3 [s]
#
# Performing hypothesis testing (H0: theta = 0, alpha = 0.05)
# Hessian approximated as J^T J
#
# Summary of parameters:
#  parameter    est                CI  width_CI  t-test  p-value
#        tt -8.220 [-27.185, 10.744]    18.965  -0.857    0.393
#     tt_cv -0.343   [-2.205, 1.519]     1.862  -0.365    0.716
# incidents -0.022   [-2.138, 2.095]     2.117  -0.020    0.984
#
# Computing F-test
#
# Summary of model:
#       F  critical-F     p   n  dof_m1  dof_m2        sse_m1        sse_m2
# 10.928       2.670 0.000 141       0       3 304774857.800 246268887.134
# Time: 680.0[s]

# %% [markdown]
# #### Refined stage

# %%
learner_refined.utility_function.initial_values = theta_norefined_feature_selection_model

learning_results_refined, inference_results_refined, best_iter_refined = \
    learner_refined.statistical_inference(h0=0, bilevel_iters=10, alpha=0.05, 
                                          link_report=False, iteration_report = True)

theta_refined_feature_selection_model = learning_results_refined[best_iter_refined]['theta']
# Out:
# Bilevel optimization for Fresno network
#
# Iteration : 1/10
#
# Initial theta: {'tt': '-8.2E+00', 'tt_cv': '-3.4E-01', 'incidents': '-2.2E-02'}
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['2E-04', '0E+00']
# Initial Fisk Objective: -679,299.18
# Final Fisk Objective: -622,732.76
# Improvement Fisk Objective: 8.33%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 199.4 [s]
# Initial objective: 223,699,396
# Initial RMSE: 1259.6
# Initial Normalized RMSE: 0.569
#
# Iteration : 2/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '-1.4E+00', 'tt_cv': '3.0E+00', 'incidents': '-2.7E-01'}
# time: 569.3[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['6E-03', '6E-04', '1E-03', '2E-04', '1E-05']
# Initial Fisk Objective: 2,746,961.93
# Final Fisk Objective: 2,789,215.85
# Improvement Fisk Objective: 1.54%
# Final gap: 1E-05. Acc. bound: 1E-04. Time: 346.7 [s]
#
# Time current iteration: 916.2 [s]
# Current objective_value: 307,715,257
# Current objective improvement: 0.00%
# Current RMSE: 1477.3
# Current Normalized RMSE: 0.667
# Marginal objective improvement: -37.56%
# Marginal objective improvement value: -84,015,861.0
#
#
# Iteration : 3/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '-9.2E+00', 'tt_cv': '1.5E+01', 'incidents': '-9.3E-01'}
# time: 620.2[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['1E-02', '1E-03', '7E-04', '0E+00']
# Initial Fisk Objective: 14,376,770.76
# Final Fisk Objective: 14,658,850.94
# Improvement Fisk Objective: 1.96%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 302.6 [s]
#
# Time current iteration: 923.1 [s]
# Current objective_value: 271,984,765
# Current objective improvement: 0.00%
# Current RMSE: 1388.9
# Current Normalized RMSE: 0.627
# Marginal objective improvement: 11.61%
# Marginal objective improvement value: 35,730,491.7
#
#
# Iteration : 4/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '1.1E+02', 'tt_cv': '-1.9E+02', 'incidents': '9.7E+00'}
# time: 723.6[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['0E+00']
# Initial Fisk Objective: -113,872,671.26
# Final Fisk Objective: -113,687,590.5
# Improvement Fisk Objective: 0.16%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 196.3 [s]
#
# Time current iteration: 920.3 [s]
# Current objective_value: 342,201,802
# Current objective improvement: 0.00%
# Current RMSE: 1557.9
# Current Normalized RMSE: 0.704
# Marginal objective improvement: -25.82%
# Marginal objective improvement value: -70,217,037.1
#
#
# Iteration : 5/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '2.9E+02', 'tt_cv': '-1.1E+03', 'incidents': '-7.6E+01'}
# time: 884.8[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['0E+00']
# Initial Fisk Objective: -742,256,238.5
# Final Fisk Objective: -742,017,360.86
# Improvement Fisk Objective: 0.03%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 228.9 [s]
#
# Time current iteration: 1114.4 [s]
# Current objective_value: 335,087,722
# Current objective improvement: 0.00%
# Current RMSE: 1541.6
# Current Normalized RMSE: 0.696
# Marginal objective improvement: 2.08%
# Marginal objective improvement value: 7,114,080.1
#
#
# Iteration : 6/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '4.6E+03', 'tt_cv': '-2.6E+02', 'incidents': '5.3E+03'}
# time: 526.3[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['8E-03', '7E-04', '1E-04', '0E+00']
# Initial Fisk Objective: 5,217,957,925.18
# Final Fisk Objective: 5,722,277,611.61
# Improvement Fisk Objective: 9.67%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 349.7 [s]
#
# Time current iteration: 876.3 [s]
# Current objective_value: 675,218,353
# Current objective improvement: 0.00%
# Current RMSE: 2188.3
# Current Normalized RMSE: 0.989
# Marginal objective improvement: -101.50%
# Marginal objective improvement value: -340,130,631.5
#
#
# Iteration : 7/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '4.7E+03', 'tt_cv': '-1.2E+03', 'incidents': '5.2E+03'}
# time: 419.1[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['9E-03', '4E-03', '5E-04', '0E+00']
# Initial Fisk Objective: 4,113,646,098.82
# Final Fisk Objective: 4,636,812,718.94
# Improvement Fisk Objective: 12.72%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 368.0 [s]
#
# Time current iteration: 787.3 [s]
# Current objective_value: 678,586,297
# Current objective improvement: 0.00%
# Current RMSE: 2193.8
# Current Normalized RMSE: 0.991
# Marginal objective improvement: -0.50%
# Marginal objective improvement value: -3,367,943.7
#
#
# Iteration : 8/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '4.7E+03', 'tt_cv': '-1.2E+03', 'incidents': '5.2E+03'}
# time: 520.3[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['9E-03', '4E-03', '5E-04', '0E+00']
# Initial Fisk Objective: 4,113,646,098.82
# Final Fisk Objective: 4,636,812,718.94
# Improvement Fisk Objective: 12.72%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 354.4 [s]
#
# Time current iteration: 875.1 [s]
# Current objective_value: 678,586,297
# Current objective improvement: 0.00%
# Current RMSE: 2193.8
# Current Normalized RMSE: 0.991
# Marginal objective improvement: 0.00%
# Marginal objective improvement value: 0.0
#
#
# Iteration : 9/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '4.7E+03', 'tt_cv': '-1.2E+03', 'incidents': '5.2E+03'}
# time: 459.5[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['9E-03', '4E-03', '5E-04', '0E+00']
# Initial Fisk Objective: 4,113,646,098.82
# Final Fisk Objective: 4,636,812,718.94
# Improvement Fisk Objective: 12.72%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 338.8 [s]
#
# Time current iteration: 798.5 [s]
# Current objective_value: 678,586,297
# Current objective improvement: 0.00%
# Current RMSE: 2193.8
# Current Normalized RMSE: 0.991
# Marginal objective improvement: 0.00%
# Marginal objective improvement value: 0.0
#
#
# Iteration : 10/10
#
# Learning params via lm (1 iters)
#
# Damping factors: ['1.0E-02']---| 0.0%
# theta: {'tt': '4.7E+03', 'tt_cv': '-1.2E+03', 'incidents': '5.2E+03'}
# time: 424.0[s]
#
# SUE via fw (max iters: 100)
# Performed path size correction with factor 1
#
# Equilibrium gaps: ['9E-03', '4E-03', '5E-04', '0E+00']
# Initial Fisk Objective: 4,113,646,098.82
# Final Fisk Objective: 4,636,812,718.94
# Improvement Fisk Objective: 12.72%
# Final gap: 0E+00. Acc. bound: 1E-04. Time: 334.8 [s]
#
# Time current iteration: 759.1 [s]
# Current objective_value: 678,586,297
# Current objective improvement: 0.00%
# Current RMSE: 2193.8
# Current Normalized RMSE: 0.991
# Marginal objective improvement: 0.00%
# Marginal objective improvement value: 0.0
#
# Summary results of bilevel optimization
# best iter: 1
# best theta: {'tt': '-8.2E+00', 'tt_cv': '-3.4E-01', 'incidents': '-2.2E-02'}
# best objective_value: 223,699,396
# Final best objective improvement: 0.00%
# Final best objective improvement value: 0.0
# Best RMSE: 1259.6
# Best Normalized RMSE: 0.569
# Total time: 7970.6 [s]
#
# Performing hypothesis testing (H0: theta = 0, alpha = 0.05)
# Hessian approximated as J^T J
#
# Summary of parameters:
#  parameter    est                CI  width_CI  t-test  p-value
#        tt -8.220 [-27.185, 10.744]    18.965  -0.857    0.393
#     tt_cv -0.343   [-2.205, 1.519]     1.862  -0.365    0.716
# incidents -0.022   [-2.138, 2.095]     2.117  -0.020    0.984
#
# Computing F-test
#
# Summary of model:
#       F  critical-F     p   n  dof_m1  dof_m2        sse_m1        sse_m2
# 10.928       2.670 0.000 141       0       3 304774857.800 246268887.134
# Time: 866.1[s]

# %% [markdown]
# #### Report

# %%
estimation_reporter.add_items_report(
    selected_date = data_reader.options['selected_date'],
    selected_hour = data_reader.options['selected_hour'],
    selected_od_periods = data_reader.options['od_periods'],
    mean_counts=round(mean_count_benchmark_model,1),
    mean_counts_prediction_loss = round(mean_counts_prediction_loss,1),
    equilikely_prediction_loss = round(equilikely_prediction_loss,1)
)

estimation_reporter.add_items_report(
    theta_norefined=theta_norefined_feature_selection_model,
    theta_refined= theta_refined_feature_selection_model,
    best_objective_norefined = round(learning_results_norefined[best_iter_norefined]['objective'],1),
    best_objective_refined = round(learning_results_refined[best_iter_refined]['objective'],1),
)

estimation_reporter.write_estimation_report(
    network=fresno_network,
    learners=[learner_norefined, learner_refined],
    utility_function=utility_function_feature_selection_model)

estimation_reporter.write_learning_tables(
    results_norefined=learning_results_norefined,
    results_refined=learning_results_refined,
    network = fresno_network,
    utility_function = utility_function_feature_selection_model)

estimation_reporter.write_inference_tables(
    results_norefined=inference_results_norefined,
    results_refined=inference_results_refined,
    float_format = '%.3f')

# %% [markdown]
# ### e) Model with all features and constrained optimization on expected signs of parameters

# %%
# Update utility functions of no refined and refined learners
learner_norefined.utility_function = utility_function_full_model
learner_refined.utility_function = utility_function_full_model

#Initialize value with the estimate obtained from b)
#learner_norefined.utility_function.initial_values = theta_refined

# %% [markdown]
# #### No refined stage

# %%
# learning_results_norefined, inference_results_norefined, best_iter_norefined = \
#     learner_norefined.statistical_inference(h0=0, bilevel_iters=3, alpha=0.05, constrained_optimization = {'sign':True, 'fix':True}, 
#                                             link_report=False, iteration_report = True)

# theta_norefined_full_model = learning_results_norefined[best_iter_norefined]['theta']

# %% [markdown]
# #### Refined stage
